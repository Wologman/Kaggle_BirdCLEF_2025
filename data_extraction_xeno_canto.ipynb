# %% [markdown]
# # Introduction
#
# Downloading any data avaiable from the Xeno-Canto Database for the birds of interest from our region.
# Modified from [here](https://www.kaggle.com/code/gpreda/download-birds-songs-recording-metadata)

# %%
import requests
import os
import pandas as pd
import json
import requests
from tqdm.notebook import tqdm
from pathlib import Path

# %%
OUTPUT_CSV_PATH =  '/media/olly/T7/Kaytoo/Data/xeno_canto_original_metadata.csv'
BIRD_MAP_PATH = '/media/olly/T7/Kaytoo/Data/bird_map_2012-13.csv'
SOUND_FILE_DOWNLOADS = '/media/olly/T7/Kaytoo/Data/Xeno_Canto_Soundfiles'
LOCAL_COUNTRIES = ['Australia', 'New Zealand', 'Vanuatu', 'Papua New Guinea', 'Solomon Islands', 'Fiji']

# %%
Path(SOUND_FILE_DOWNLOADS).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# The functions used to download content from **xeno-canto-org** are the following:
#
# * **get_first_page_per_country** - get, for a specific country, the first page of response, as well as metadata for the next pages;
# * **get_page_per_country** - get a specific page per country - this is called after a first page was downloaded and is called for each subsequent page;
# * **inspect_json** - print metadata for the first response;
# * **get_recordings** - retrieve payload from a downloaded page;
# * **download_suite_from_country** - end-to-end suite for downloading content for a specific country - call the above described functions.

# %%
def get_first_page_per_bird(gen, sp):
    """
    @country: the country for which we download metadata content 
    @returns: the content downloaded
    """
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=gen:{gen} {sp} ssp:\"= \""
    response = requests.get(api_search)
    if response.status_code == 200:
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None

def get_page_per_bird(gen, sp, page):
    """
    @country: the country for which we download metadata content 
    @returns: the content downloaded
    """
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=gen:{gen} {sp} ssp:\"= \"&page={page}"
    response = requests.get(api_search)
    if response.status_code == 200:
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None

def get_first_page_per_country(country):
    """
    @country: the country for which we download metadata content 
    @returns: the content downloaded
    """
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=cnt:{country}"
    response = requests.get(api_search)
    if response.status_code == 200:
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None
    
def get_page_per_country(country, page):
    """
    @country: the country for which we download metadata content 
    @page: the current page to be downloaded
    @returns: the content downloaded
    """
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=cnt:{country}&page={page}"
    response = requests.get(api_search)
    if response.status_code == 200:
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None

def inspect_json(json_data):
    """
    @json_data: json data to be inspected
    """
    print(f"recordings: {json_data['numRecordings']}")
    print(f"species: {json_data['numSpecies']}")
    print(f"page: {json_data['page']}")
    print(f"number pages: {json_data['numPages']}")

def inspect_bird_json(json_data):
    print(f"recordings: {json_data['numRecordings']}")

def get_recordings(payload):
    """
    @payload: json data from which we extract the bird recordings metadata collection
    @returns: birds recordings metadata collection
    """
    return payload["recordings"]

def download_suite_from_country(country, country_initial_payload):
    """
    @country: the country for which we download metadata content 
    @country_initial_payload: the initial downloaded payload for the country (1st page). We download all the other pages.
    @returns: the content recordings (all pages, including the original one)
    """
    pages = country_initial_payload["numPages"]
    
    all_recordings = []
    all_recordings = all_recordings + get_recordings(country_initial_payload)
    for page in tqdm(range(2,pages+1)):
        payload = get_page_per_country(country, page)
        recordings = get_recordings(payload)
        all_recordings = all_recordings + recordings
    
    return all_recordings

def download_suite_for_bird(gen, sp, bird_initial_payload):
    """
    @country: the country for which we download metadata content 
    @country_initial_payload: the initial downloaded payload for the country (1st page). We download all the other pages.
    @returns: the content recordings (all pages, including the original one)
    """
    pages = bird_initial_payload["numPages"]
    
    all_recordings = []
    all_recordings = all_recordings + get_recordings(bird_initial_payload)
    for page in range(2,pages+1):
        payload = get_page_per_bird(gen, sp, page)
        recordings = get_recordings(payload)
        all_recordings = all_recordings + recordings
    
    return all_recordings

# %% [markdown]
# Make an e-bird to scientific name map

# %%
bird_name_df = pd.read_csv(BIRD_MAP_PATH)
bird_name_df.head()
# Out:
#    Code    CommonName    eBird         ScientificName
# 0     1     Silvereye  silver3    Zosterops lateralis
# 1     2      Bellbird  nezbel1     Anthornis melanura
# 2     3  Grey Warbler  gryger1         Gerygone igata
# 3     4        Tomtit  tomtit1  Petroica macrocephala
# 4     5        Tomtit  tomtit1  Petroica macrocephala

# %%
bird_name_df['ScientificName'].unique()
# Out:
# array(['Zosterops lateralis', 'Anthornis melanura', 'Gerygone igata',
#        'Petroica macrocephala', 'Fringilla coelebs',
#        'Rhipidura fuliginosa ', 'Rhipidura atra', 'Turdus merula ',
#        'Prosthemadera novaeseelandiae', 'Acanthisitta chloris ',
#        'Hemiphaga novaeseelandiae', 'Petroica longipes',
#        'Petroica australis', 'Sturnus vulgaris', 'Cyanoramphus auriceps',
#        'Prunella modularis', 'Ixobrychus novaezelandiae',
#        'Certhia americana', 'Emberiza cirlus', 'Alectoris chukar',
#        'Cacatua sulphurea', 'Fulica sp.', 'Zapornia pusilla',
#        'Zapornia tabuensis', 'Urodynamis taitensis',
#        'Chrysococcyx lucidus', 'Tachybaptus ruficollis',
#        'Charadrius bicinctus', 'Charadrius melanops',
#        'Anarhynchus obscurus', 'Anas platyrhynchos x superciliosa',
#        'Hymenolaimus malacorhynchos', 'Anas superciliosa',
#        'Anas platyrhynchos', 'Bubulcus ibis', 'Egretta garzetta',
#        'Falco novaeseelandiae', 'Poodytes punctatus', 'Morus serrator',
#        'Carduelis carduelis', 'Branta canadensis', 'Podiceps cristatus',
#        'Chloris chloris', 'Numida meleagris', 'Chroicocephalus bulleri',
#        'Chroicocephalus novaehollandiae scopulinus', 'Larus dominicanus',
#        'Circus approximans', 'Nycticorax caledonicus', 'Ardea alba ',
#        'Egretta novaehollandiae', 'Plegadis falcinellus',
#        'Nestor meridionalis ', 'Strigops habroptila ', 'Nestor notabilis',
#        'Todiramphus sanctus ', 'Apteryx australis', 'Apteryx haastii',
#        'Apteryx owenii', 'Apteryx mantelli', 'Callaeas wilsoni',
#        'Gymnorhina tibicen', 'Mohoua ochrocephala',
#        'Ninox novaeseelandiae', 'Acridotheres tristis', 'Athene noctua',
#        'Haematopus bachmani', 'Haematopus chathamensis',
#        'Haematopus finschi ', 'Haematopus unicolor',
#        'Cyanoramphus malherbi', 'Cyanoramphus novaezelandiae',
#        'Alectoris rufa', 'Pavo cristatus', 'Eudyptula minor',
#        'Megadyptes antipodes', 'Phasianus colchicus', 'Columba livia',
#        'Anthus novaeseelandiae', 'Vanellus miles', 'Porphyrio melanotus',
#        'Synoicus ypsilophorus ', 'Callipepla californica',
#        'Gallirallus philippensis', 'Acanthis flammea',
#        'Corvus frugilegus ', 'Platycercus elegans', 'Platycercus eximius',
#        'Philesturnus rufusater', 'Philesturnus carunculatus',
#        'Aythya novaeseelandiae', 'Phalacrocorax carbo',
#        'Phalacrocorax punctatus', 'Microcarbo melanoleucos',
#        'Phalacrocorax sulcirostris', 'Phalacrocorax varius',
#        'Tadorna variegata', 'Spatula rhynchotis', 'Alauda arvensis',
#        'Passer domesticus domesticus', 'Platalea regia',
#        'Himantopus novaezelandiae', 'Himantopus leucocephalus',
#        'Notiomystis cincta', 'Hirundo neoxena', 'Cygnus atratus',
#        'Cygnus olor ', 'Porphyrio hochstetteri', 'Anas chlorotis',
#        'Anas gracilis', 'Chlidonias albostriatus', 'Hydroprogne caspia',
#        'Sternula nereis', 'Sterna striata', 'Anous albivittus ',
#        'Turdus philomelos', 'Meleagris gallopavo', 'Arenaria interpres',
#        'vitriolix', 'Gallirallus australis', 'Mohoua albicilla',
#        'Xenicus gilviventris', 'Anarhynchus frontalis',
#        'Emberiza citrinella'], dtype=object)

# %%
sci_ebird_map = dict(zip(bird_name_df['ScientificName'], bird_name_df['eBird']))

# %% [markdown]
# ### 3. Application: download all metadata of recordings from a country
#
# We are using the utility funtions to download and save the meta information for birdsongs recording for a specific country.

# %%
def download_save_all_meta_for_country(country):
    birds = get_first_page_per_country(country)
    inspect_json(birds)
    print(f"recordings in first batch: {len(get_recordings(birds))}")
    suite = download_suite_from_country(country, birds)
    data_df = pd.DataFrame.from_records(suite)
    print(f"suite length: {data_df.shape[0]}")
    return data_df

# %%
def download_save_all_meta_for_bird(gen, sp):
    birds = get_first_page_per_bird(gen, sp)
    inspect_bird_json(birds)
    print(f"recordings in first batch: {len(get_recordings(birds))}")
    suite = download_suite_for_bird(gen, sp, birds)
    data_df = pd.DataFrame.from_records(suite)
    print(f"suite length: {data_df.shape[0]}")
    return data_df

# %% [markdown]
# Try filtering by cnt == 'New Zealand'

# %%
nz_df = download_save_all_meta_for_country('New Zealand')
# Out:
# recordings: 203
# species: 11
# page: 1
# number pages: 1
# recordings in first batch: 203
# 0it [00:00, ?it/s]
# suite length: 203

# %%
nz_df.head(3)
# Out:
#        id        gen               sp ssp  group                  en  \
# 0  198201     Aythya  novaeseelandiae      birds   New Zealand Scaup
# 1  293310  Hemiphaga  novaeseelandiae      birds  New Zealand Pigeon
# 2  378290  Hemiphaga  novaeseelandiae      birds  New Zealand Pigeon
#
#                     rec          cnt  \
# 0           nick talbot  New Zealand
# 1              Dan Lane  New Zealand
# 2  Matthias Feuersenger  New Zealand
#
#                                                  loc       lat  ...  \
# 0           Rotorua, Rotorua District, Bay Of Plenty  -38.1101  ...
# 1                           Tiritiri Matangi Island    -36.601  ...
# 2  Blumine Island, Marlborough District, Marlborough  -41.1706  ...
#
#                                                  rmk bird-seen animal-seen  \
# 0   A small flock of birds swimming on Lake Rotorua.       yes         yes
# 1  Natural song from a bird perched about 2m up i...       yes         yes
# 2  New Zealand Pigeon calmly sitting in mid strat...       yes         yes
#
#   playback-used temp regnr auto dvc mic    smp
# 0            no              no          44100
# 1            no              no          44100
# 2            no              no          44100
#
# [3 rows x 38 columns]

# %%
nz_df.shape
# Out:
# (203, 38)

# %%
bird_dfs = []
for bird in tqdm(sci_ebird_map.keys()):
    print(f'Downloading metadata for {sci_ebird_map[bird]}')
    bird_name = bird.split()
    if len(bird_name) == 2:
        gen, sp = bird_name
        bird_df = download_save_all_meta_for_bird(gen, sp)
        if not bird_df.empty:
            bird_dfs.append(bird_df)

df = pd.concat(bird_dfs).reset_index(drop=True)
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# Downloading metadata for silver3
# recordings: 78
# recordings in first batch: 78
# suite length: 78
# Downloading metadata for nezbel1
# recordings: 62
# recordings in first batch: 62
# suite length: 62
# Downloading metadata for gryger1
# recordings: 28
# recordings in first batch: 28
# suite length: 28
# Downloading metadata for tomtit1
# recordings: 12
# recordings in first batch: 12
# suite length: 12
# Downloading metadata for comcha
# recordings: 5032
# recordings in first batch: 500
# suite length: 5032
# Downloading metadata for nezfan1
# recordings: 21
# recordings in first batch: 21
# suite length: 21
# Downloading metadata for blafan1
# recordings: 11
# recordings in first batch: 11
# suite length: 11
# Downloading metadata for eurbla
# recordings: 5989
# recordings in first batch: 500
# suite length: 5989
# Downloading metadata for tui1
# recordings: 95
# recordings in first batch: 95
# suite length: 95
# Downloading metadata for riflem1
# recordings: 25
# recordings in first batch: 25
# suite length: 25
# Downloading metadata for nezpig2
# recordings: 8
# recordings in first batch: 8
# suite length: 8
# Downloading metadata for nezrob2
# recordings: 21
# recordings in first batch: 21
# suite length: 21
# Downloading metadata for nezrob3
# recordings: 13
# recordings in first batch: 13
# suite length: 13
# Downloading metadata for eursta
# recordings: 1497
# recordings in first batch: 500
# suite length: 1497
# Downloading metadata for yefpar3
# recordings: 11
# recordings in first batch: 11
# suite length: 11
# Downloading metadata for dunnoc1
# recordings: 1988
# recordings in first batch: 500
# suite length: 1988
# Downloading metadata for nezbit1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for brncre
# recordings: 247
# recordings in first batch: 247
# suite length: 247
# Downloading metadata for cirbun1
# recordings: 959
# recordings in first batch: 500
# suite length: 959
# Downloading metadata for chukar
# recordings: 82
# recordings in first batch: 82
# suite length: 82
# Downloading metadata for succoc
# recordings: 10
# recordings in first batch: 10
# suite length: 10
# Downloading metadata for coot1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for baicra4
# recordings: 353
# recordings in first batch: 353
# suite length: 353
# Downloading metadata for spocra2
# recordings: 25
# recordings in first batch: 25
# suite length: 25
# Downloading metadata for lotkoe1
# recordings: 14
# recordings in first batch: 14
# suite length: 14
# Downloading metadata for shbcuc1
# recordings: 39
# recordings in first batch: 39
# suite length: 39
# Downloading metadata for litgre1
# recordings: 1488
# recordings in first batch: 500
# suite length: 1488
# Downloading metadata for dobplo1
# recordings: 11
# recordings in first batch: 11
# suite length: 11
# Downloading metadata for blfdot1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for rebdot1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for x00458
# Downloading metadata for bluduc1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for pabduc1
# recordings: 20
# recordings in first batch: 20
# suite length: 20
# Downloading metadata for mallar3
# recordings: 1127
# recordings in first batch: 500
# suite length: 1127
# Downloading metadata for categr1
# recordings: 277
# recordings in first batch: 277
# suite length: 277
# Downloading metadata for litegr
# recordings: 497
# recordings in first batch: 497
# suite length: 497
# Downloading metadata for nezfal1
# recordings: 3
# recordings in first batch: 3
# suite length: 3
# Downloading metadata for fernbi1
# recordings: 21
# recordings in first batch: 21
# suite length: 21
# Downloading metadata for ausgan1
# recordings: 4
# recordings in first batch: 4
# suite length: 4
# Downloading metadata for eurgol
# recordings: 1934
# recordings in first batch: 500
# suite length: 1934
# Downloading metadata for cangoo
# recordings: 586
# recordings in first batch: 500
# suite length: 586
# Downloading metadata for grcgre1
# recordings: 329
# recordings in first batch: 329
# suite length: 329
# Downloading metadata for eurgre1
# recordings: 2014
# recordings in first batch: 500
# suite length: 2014
# Downloading metadata for helgui6
# recordings: 109
# recordings in first batch: 109
# suite length: 109
# Downloading metadata for blbgul1
# recordings: 10
# recordings in first batch: 10
# suite length: 10
# Downloading metadata for rebgul1
# Downloading metadata for kelgul
# recordings: 77
# recordings in first batch: 77
# suite length: 77
# Downloading metadata for swahar1
# recordings: 10
# recordings in first batch: 10
# suite length: 10
# Downloading metadata for runher1
# recordings: 6
# recordings in first batch: 6
# suite length: 6
# Downloading metadata for greegr
# recordings: 297
# recordings in first batch: 297
# suite length: 297
# Downloading metadata for whfher1
# recordings: 17
# recordings in first batch: 17
# suite length: 17
# Downloading metadata for gloibi
# recordings: 143
# recordings in first batch: 143
# suite length: 143
# Downloading metadata for nezkak1
# recordings: 33
# recordings in first batch: 33
# suite length: 33
# Downloading metadata for kakapo2
# recordings: 1
# recordings in first batch: 1
# suite length: 1
# Downloading metadata for kea1
# recordings: 12
# recordings in first batch: 12
# suite length: 12
# Downloading metadata for sackin1
# recordings: 40
# recordings in first batch: 40
# suite length: 40
# Downloading metadata for sobkiw2
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for grskiw1
# recordings: 7
# recordings in first batch: 7
# suite length: 7
# Downloading metadata for liskiw1
# recordings: 5
# recordings in first batch: 5
# suite length: 5
# Downloading metadata for nibkiw1
# recordings: 21
# recordings in first batch: 21
# suite length: 21
# Downloading metadata for kokako3
# recordings: 20
# recordings in first batch: 20
# suite length: 20
# Downloading metadata for ausmag2
# recordings: 65
# recordings in first batch: 65
# suite length: 65
# Downloading metadata for yellow3
# recordings: 26
# recordings in first batch: 26
# suite length: 26
# Downloading metadata for morepo2
# recordings: 27
# recordings in first batch: 27
# suite length: 27
# Downloading metadata for commyn
# recordings: 240
# recordings in first batch: 240
# suite length: 240
# Downloading metadata for litowl1
# recordings: 1341
# recordings in first batch: 500
# suite length: 1341
# Downloading metadata for blkoys
# recordings: 29
# recordings in first batch: 29
# suite length: 29
# Downloading metadata for chaoys1
# recordings: 5
# recordings in first batch: 5
# suite length: 5
# Downloading metadata for soioys1
# recordings: 12
# recordings in first batch: 12
# suite length: 12
# Downloading metadata for varoys1
# recordings: 24
# recordings in first batch: 24
# suite length: 24
# Downloading metadata for malpar2
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for refpar4
# recordings: 12
# recordings in first batch: 12
# suite length: 12
# Downloading metadata for relpar1
# recordings: 343
# recordings in first batch: 343
# suite length: 343
# Downloading metadata for compea
# recordings: 105
# recordings in first batch: 105
# suite length: 105
# Downloading metadata for litpen1
# recordings: 16
# recordings in first batch: 16
# suite length: 16
# Downloading metadata for yeepen1
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for rinphe1
# recordings: 625
# recordings in first batch: 500
# suite length: 625
# Downloading metadata for rocpig
# recordings: 192
# recordings in first batch: 192
# suite length: 192
# Downloading metadata for auspip3
# recordings: 9
# recordings in first batch: 9
# suite length: 9
# Downloading metadata for maslap1
# recordings: 31
# recordings in first batch: 31
# suite length: 31
# Downloading metadata for purswa6
# recordings: 42
# recordings in first batch: 42
# suite length: 42
# Downloading metadata for broqua1
# recordings: 15
# recordings in first batch: 15
# suite length: 15
# Downloading metadata for calqua
# recordings: 188
# recordings in first batch: 188
# suite length: 188
# Downloading metadata for bubrai1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for comred
# recordings: 542
# recordings in first batch: 500
# suite length: 542
# Downloading metadata for rook1
# recordings: 647
# recordings in first batch: 500
# suite length: 647
# Downloading metadata for criros2
# recordings: 43
# recordings in first batch: 43
# suite length: 43
# Downloading metadata for easros1
# recordings: 40
# recordings in first batch: 40
# suite length: 40
# Downloading metadata for saddle2
# recordings: 25
# recordings in first batch: 25
# suite length: 25
# Downloading metadata for saddle3
# recordings: 7
# recordings in first batch: 7
# suite length: 7
# Downloading metadata for nezsca1
# recordings: 1
# recordings in first batch: 1
# suite length: 1
# Downloading metadata for grecor
# recordings: 200
# recordings in first batch: 200
# suite length: 200
# Downloading metadata for sposha1
# recordings: 7
# recordings in first batch: 7
# suite length: 7
# Downloading metadata for lipcor1
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for libcor1
# recordings: 8
# recordings in first batch: 8
# suite length: 8
# Downloading metadata for piecor1
# recordings: 3
# recordings in first batch: 3
# suite length: 3
# Downloading metadata for parshe1
# recordings: 16
# recordings in first batch: 16
# suite length: 16
# Downloading metadata for aussho1
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for brnsku3
# recordings: 2188
# recordings in first batch: 500
# suite length: 2188
# Downloading metadata for houspa
# Downloading metadata for royspo1
# recordings: 3
# recordings in first batch: 3
# suite length: 3
# Downloading metadata for blasti1
# recordings: 7
# recordings in first batch: 7
# suite length: 7
# Downloading metadata for piesti1
# recordings: 50
# recordings in first batch: 50
# suite length: 50
# Downloading metadata for stitch1
# recordings: 34
# recordings in first batch: 34
# suite length: 34
# Downloading metadata for welswa1
# recordings: 27
# recordings in first batch: 27
# suite length: 27
# Downloading metadata for blkswa
# recordings: 49
# recordings in first batch: 49
# suite length: 49
# Downloading metadata for mutswa
# recordings: 589
# recordings in first batch: 500
# suite length: 589
# Downloading metadata for takahe3
# recordings: 6
# recordings in first batch: 6
# suite length: 6
# Downloading metadata for brotea1
# recordings: 2
# recordings in first batch: 2
# suite length: 2
# Downloading metadata for gretea1
# recordings: 35
# recordings in first batch: 35
# suite length: 35
# Downloading metadata for blfter1
# recordings: 7
# recordings in first batch: 7
# suite length: 7
# Downloading metadata for caster1
# recordings: 378
# recordings in first batch: 378
# suite length: 378
# Downloading metadata for faiter2
# recordings: 4
# recordings in first batch: 4
# suite length: 4
# Downloading metadata for whfter1
# recordings: 14
# recordings in first batch: 14
# suite length: 14
# Downloading metadata for grynod1
# recordings: 0
# recordings in first batch: 0
# suite length: 0
# Downloading metadata for sonthr1
# recordings: 4399
# recordings in first batch: 500
# suite length: 4399
# Downloading metadata for wiltur
# recordings: 103
# recordings in first batch: 103
# suite length: 103
# Downloading metadata for rudtur
# recordings: 439
# recordings in first batch: 439
# suite length: 439
# Downloading metadata for spybird
# Downloading metadata for weka1
# recordings: 11
# recordings in first batch: 11
# suite length: 11
# Downloading metadata for whiteh1
# recordings: 30
# recordings in first batch: 30
# suite length: 30
# Downloading metadata for soiwre1
# recordings: 8
# recordings in first batch: 8
# suite length: 8
# Downloading metadata for wrybil1
# recordings: 10
# recordings in first batch: 10
# suite length: 10
# Downloading metadata for yellow2
# recordings: 2708
# recordings in first batch: 500
# suite length: 2708

# %%
df.head()
# Out:
#        id        gen         sp ssp  group         en           rec  \
# 0  895593  Zosterops  lateralis      birds  Silvereye  Drew Davison
# 1  841102  Zosterops  lateralis      birds  Silvereye       Sreekar
# 2  836020  Zosterops  lateralis      birds  Silvereye       Sreekar
# 3  821562  Zosterops  lateralis      birds  Silvereye   David Boyle
# 4  821561  Zosterops  lateralis      birds  Silvereye   David Boyle
#
#            cnt                                                loc       lat  \
# 0    Australia  Lions Dryandra Woodland Village, Shire of Cuba...  -32.7833
# 1    Australia          Coral Sea, Gladstone Regional, Queensland  -23.4423
# 2    Australia               Carindale, Brisbane City, Queensland  -27.5289
# 3  New Zealand                        Taiko Camp, Chatham Island   -44.0742
# 4  New Zealand                        Taiko Camp, Chatham Island   -44.0742
#
#    ...                rmk bird-seen animal-seen playback-used temp regnr auto  \
# 0  ...                          yes         yes            no              no
# 1  ...                           no          no            no              no
# 2  ...                           no          no            no              no
# 3  ...                           no          no            no             yes
# 4  ...  Both common calls        no          no            no             yes
#
#            dvc                                     mic    smp
# 0  Samsung S22                                          44100
# 1      Zoom F3                               Rode NTG2  44100
# 2      Zoom F3                               Rode NTG2  48000
# 3      Zoom H5  Clippy XLR EM272Z1 Matched Stereo Pair  48000
# 4      Zoom H5  Clippy XLR EM272Z1 Matched Stereo Pair  48000
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['id', 'gen', 'sp', 'ssp', 'group', 'en', 'rec', 'cnt', 'loc', 'lat',
#        'lng', 'alt', 'type', 'sex', 'stage', 'method', 'url', 'file',
#        'file-name', 'sono', 'osci', 'lic', 'q', 'length', 'time', 'date',
#        'uploaded', 'also', 'rmk', 'bird-seen', 'animal-seen', 'playback-used',
#        'temp', 'regnr', 'auto', 'dvc', 'mic', 'smp'],
#       dtype='object')

# %%
df.shape
# Out:
# (41736, 38)

# %%
df['cnt'].unique()
# Out:
# array(['Australia', 'New Zealand', 'Vanuatu', 'Lithuania', 'Spain',
#        'Italy', 'France', 'Portugal', 'Estonia', 'Sweden',
#        'United Kingdom', 'Germany', 'Ireland', 'Poland', 'Norway',
#        'Greece', 'Bulgaria', 'Russian Federation', 'Denmark',
#        'Netherlands', 'Belgium', 'Hungary', 'Turkey', 'Croatia',
#        'Slovakia', 'Ukraine', 'Albania', 'Finland', 'Cyprus',
#        'Czech Republic', 'Romania', 'Azerbaijan', 'Georgia', 'Austria',
#        'Switzerland', 'Latvia', 'Belarus', 'Bosnia Herzegovina', 'Malta',
#        'Luxembourg', 'Andorra', 'Serbia', 'Morocco', 'South Africa',
#        'Iran', 'Montenegro', 'India', 'China', 'Papua New Guinea',
#        'Indonesia', 'Iceland', 'Kyrgyzstan', 'Jordan', 'Uzbekistan',
#        'Israel', 'Libya', 'Slovenia', 'Tunisia', 'Canada',
#        'Liechtenstein', 'United States', 'Argentina', 'Mexico',
#        'Kazakhstan', 'Malaysia', 'Brazil', 'Guatemala', 'El Salvador',
#        'Macedonia', 'Algeria', 'Mongolia', 'East Timor', 'Singapore',
#        'Mozambique', 'Ethiopia', 'Congo (Brazzaville)', 'Taiwan',
#        'Tanzania', 'United Arab Emirates', 'Thailand', 'Sri Lanka',
#        'Namibia', 'Saudi Arabia', 'Ghana', 'Myanmar', 'Kenya',
#        'South Korea', 'Japan', 'Colombia', 'Panama', 'Senegal',
#        'St Lucia', 'Zambia', 'Venezuela', 'Madagascar', 'Ecuador',
#        'Nigeria', 'Chile', 'Costa Rica', 'Uganda', 'Dominican Republic',
#        'Bolivia', 'Honduras', 'Botswana', 'Vietnam', 'Philippines',
#        'Egypt', 'Uruguay', 'Bhutan', 'Cape Verde', 'Zimbabwe', 'Peru',
#        'Antarctica', 'Solomon Islands', '', 'Oman', 'Cambodia',
#        'Nicaragua', 'Gambia', 'Armenia', 'Mauritius', 'Seychelles',
#        'Fiji', 'Bahrain', 'Pakistan', 'Nepal', 'Guinea', 'Guinea-Bissau',
#        'Mauritania', 'French Guiana'], dtype=object)

# %%
df=df[df['cnt'].isin(LOCAL_COUNTRIES)]
df.shape

# %%
urls = df['file'].to_list()

def extract_file_extension(file_name):
    return file_name.split('.')[-1]

df['extensions'] = df['file-name'].apply(extract_file_extension)
df['new_file_name'] = 'XC' + df['id'] + '_' + df['gen'] + '_' + df['sp'] + '.' + df['extensions']
file_names = df['new_file_name'].to_list()

# %%
file_names[:5]
# Out:
# ['XC895593_Zosterops_lateralis.mp3',
#  'XC841102_Zosterops_lateralis.mp3',
#  'XC836020_Zosterops_lateralis.mp3',
#  'XC821562_Zosterops_lateralis.wav',
#  'XC821561_Zosterops_lateralis.wav']

# %%
df.columns
# Out:
# Index(['id', 'gen', 'sp', 'ssp', 'group', 'en', 'rec', 'cnt', 'loc', 'lat',
#        'lng', 'alt', 'type', 'sex', 'stage', 'method', 'url', 'file',
#        'file-name', 'sono', 'osci', 'lic', 'q', 'length', 'time', 'date',
#        'uploaded', 'also', 'rmk', 'bird-seen', 'animal-seen', 'playback-used',
#        'temp', 'regnr', 'auto', 'dvc', 'mic', 'smp', 'extensions',
#        'new_file_name'],
#       dtype='object')

# %%
df[['length']].head()
# Out:
#   length
# 0   1:12
# 1   0:29
# 2   1:03
# 3   0:57
# 4   0:55

# %%
df_bad_fantail = df[(df['gen'] == 'Rhipidura') & (df['sp']=='atra')]
df_bad_fantail.head(3)
# Out:
#           id        gen    sp ssp  group             en                 rec  \
# 5233  596215  Rhipidura  atra      birds  Black Fantail        Scott Connop
# 5234  548451  Rhipidura  atra      birds  Black Fantail  Nikolaos Sarikakis
# 5235  141932  Rhipidura  atra      birds  Black Fantail       Frank Lambert
#
#                    cnt                                                loc  \
# 5233  Papua New Guinea        Below Tari Gap, Southern Highlands Province
# 5234  Papua New Guinea  Mount Hagen, Dei District, Western Highlands P...
# 5235  Papua New Guinea                         Kumul Lodge, Enga province
#
#           lat  ... animal-seen playback-used temp regnr auto dvc mic    smp  \
# 5233  -5.9703  ...         yes            no              no          44100
# 5234  -5.8582  ...     unknown       unknown              no          48000
# 5235  -5.7912  ...         yes            no              no          44100
#
#      extensions                new_file_name
# 5233        mp3  XC596215_Rhipidura_atra.mp3
# 5234        mp3  XC548451_Rhipidura_atra.mp3
# 5235        mp3  XC141932_Rhipidura_atra.mp3
#
# [3 rows x 40 columns]

# %% [markdown]
# Remove those dodgy foreign fantails

# %%
df=df[~((df['gen'] == 'Rhipidura') + (df['sp']=='atra'))]
df.shape
# Out:
# (1583, 40)

# %%
cols_to_keep = ['id', 'gen', 'sp', 'en', 'also', 'cnt','lat', 'lng', 'rec', 'type',  'length', 'new_file_name',]
df[cols_to_keep].to_csv(OUTPUT_CSV_PATH, index=False)
df[cols_to_keep].head()
# Out:
#        id        gen         sp         en  \
# 0  895593  Zosterops  lateralis  Silvereye
# 1  841102  Zosterops  lateralis  Silvereye
# 2  836020  Zosterops  lateralis  Silvereye
# 3  821562  Zosterops  lateralis  Silvereye
# 4  821561  Zosterops  lateralis  Silvereye
#
#                                                 also          cnt       lat  \
# 0  [Phylidonyris novaehollandiae, Anthochaera car...    Australia  -32.7833
# 1                        [Hypotaenidia philippensis]    Australia  -23.4423
# 2                                                 []    Australia  -27.5289
# 3                                                 []  New Zealand  -44.0742
# 4                                                 []  New Zealand  -44.0742
#
#          lng           rec               type length  \
# 0    116.972  Drew Davison               call   1:12
# 1   151.9148       Sreekar               song   0:29
# 2   153.1227       Sreekar               song   1:03
# 3  -176.6368   David Boyle               call   0:57
# 4  -176.6368   David Boyle  call, flight call   0:55
#
#                       new_file_name
# 0  XC895593_Zosterops_lateralis.mp3
# 1  XC841102_Zosterops_lateralis.mp3
# 2  XC836020_Zosterops_lateralis.mp3
# 3  XC821562_Zosterops_lateralis.wav
# 4  XC821561_Zosterops_lateralis.wav

# %%
def download_file(url, save_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        
        with open(save_path, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
                
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")

for url, name in tqdm(zip(urls,file_names), total=len(urls), desc="Downloading files"):
    save_path = os.path.join(SOUND_FILE_DOWNLOADS, name)
    download_file(url, save_path)
# Out:
# Downloading files:   0%|          | 0/1613 [00:00<?, ?it/s]
