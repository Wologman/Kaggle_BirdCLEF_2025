# %%
use_case = {
            'experiment' : 1,
            #'project_root': '/home/olly/Desktop/Kaggle_BC25',
            #'project_root': r'C:\Users\ollyp\OneDrive\Desktop\Kaggle_BC25'
            'project_root': '/media/olly/Red_SSD/Kaggle_BC25',
            'remake_crops': False
            }

# %%
import shutil
import numpy as np
import pandas as pd
import soundfile as sf
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from joblib import Parallel, delayed
import librosa
from IPython.display import Audio 
from tqdm import tqdm
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
from pydub import AudioSegment
import torchaudio
from scipy.signal import resample
pd.set_option('display.max_colwidth', None)

# %%
class Stop: #bold red
    S = '\033[1m' + '\033[91m'
    E = '\033[0m'
    
class Go: #bold green
    S = '\033[1m' + '\033[32m'
    E = '\033[0m'
    
class Blue: #for general info
    S = '\033[94m'
    E = '\033[0m'

# %%
class FilePaths:
    def __init__(self, options=None):
        _project_dir = Path(options['project_root'])
        self.DATA_FOLDER = _project_dir / 'Data'
        self.ORIGINAL_AUDIO = self.DATA_FOLDER / 'Original_Data/birdclef-2025/train_audio'
        self.MODIFIED_AUDIO = self.DATA_FOLDER / 'Cropped_Train_Audio'
        self.MARKED_LABELS = self.DATA_FOLDER / 'Train_Metadata' / 'marked_labels.parquet'
        self.KAGGLE_LABELS_PLUS_DURATION = self.DATA_FOLDER / 'Train_Metadata' / 'aux_labels.parquet'
        self.CROP_LABELS_PATH = self.DATA_FOLDER / 'Train_Metadata/cropped_audio_labels.parquet'

        if not self.MODIFIED_AUDIO.exists:
            shutil.rmtree(self.MODIFIED_AUDIO)  # remove the old one
        self.MODIFIED_AUDIO.mkdir(parents=True, exist_ok=True)

paths = FilePaths(use_case)

# %%
class Config():
    def __init__(self, options=None):
        self.DEFAULT_LENGTH = 48
        self.OUTPUT_FILE_TYPE = '.flac'
        self.OUTPUT_DEPTH = 16
        self.SAVE_SOUNDFILES = options['remake_crops'] if options is not None else True 
        self.SR = 32000
        self.DEBUG = False

# %%
cfg = Config(use_case)

# %%
#bird_map = BirdCodeConverter(paths.INPUT_BIRD_MAP)

# %% [markdown]
# ## Helper Functions

# %%
def load_file(path):
    try:
        waveform, sr = torchaudio.load(path)
        y = waveform.numpy()
        if y.shape[0] == 2:
            y = y.mean(axis=0)
        else:
            y = y.squeeze()

        loaded_length = len(y)//sr
        if loaded_length <= 1:
            print(f'Warning, the loaded clip length is only {loaded_length} seconds for the file {path}')
        return y, sr
    except Exception as e:
        print(f"Error processing file {path}: {e}")
        return None, None

# %%
def plot_continuous(df, column_name, x_max=None, x_min=None, bins=None):
    plt.figure(figsize=(6, 4))
    ax = sns.histplot(df[column_name], bins=bins, kde=True)
    plt.title(f'Distribution of {column_name} with {bins} Bins and KDE')
    plt.xlabel(column_name)
    ax.set(xlim=(x_min, x_max) if x_min is not None and x_max is not None else None)
    plt.ylabel('Count')
    plt.show()
   
def map_names(row, mapping):
    common_name = mapping[row['primary_label']][0]
    scientific_name = mapping[row['primary_label']][1]
    return pd.Series([common_name, scientific_name], index=['common_name', 'scientific_name'])

def process_time(x):
    if pd.isna(x):
        return np.NaN
    else:
        minutes, seconds = map(int, x.split(':'))
        return int(minutes * 60 + seconds)

# %% [markdown]
# ## Load Metadata

# %%
df_marked = pd.read_parquet(paths.MARKED_LABELS, engine="pyarrow")
df_marked.head(3)
# Out:
#                filename primary_label collection             author  \
# 0   528041/CSA36365.ogg        528041        CSA  Fabio A. Sarria-S
# 1   528041/CSA36359.ogg        528041        CSA  Fabio A. Sarria-S
# 2  1139490/CSA36385.ogg       1139490        CSA  Fabio A. Sarria-S
#
#             common_name    class secondary_labels    duration centres  \
# 0    Orophus conspersus  insecta             ['']  112.417563   [4.1]
# 1    Orophus conspersus  insecta             ['']  101.033469   [4.1]
# 2  Ragoniella pulchella  insecta             ['']   98.853375   [4.0]
#
#                date_reviewed
# 0 2025-03-30 17:26:38.846914
# 1 2025-03-30 17:26:52.355833
# 2 2025-03-30 17:27:03.258653

# %%
df_marked.shape
# Out:
# (20255, 10)

# %%
df = pd.read_parquet(paths.KAGGLE_LABELS_PLUS_DURATION, engine="pyarrow")
df.head(3)
# Out:
#                filename primary_label collection             author  \
# 0  1139490/CSA36385.ogg       1139490        CSA  Fabio A. Sarria-S
# 1  1139490/CSA36389.ogg       1139490        CSA  Fabio A. Sarria-S
# 2  1192948/CSA36358.ogg       1192948        CSA  Fabio A. Sarria-S
#
#              common_name    class secondary_labels    duration
# 0   Ragoniella pulchella  insecta             ['']   98.853375
# 1   Ragoniella pulchella  insecta             ['']   96.537719
# 2  Oxyprora surinamensis  insecta             ['']  116.599812

# %%
df.shape
# Out:
# (28564, 8)

# %% [markdown]
# Let's check an example

# %%
random_row = df.sample(n=1)
fn= str(paths.ORIGINAL_AUDIO / random_row['filename'].item())
duration = random_row['duration'].item()
print(f'The file {fn} has a duration of {duration} seconds')
Audio(fn, rate=32000)
# Out:
# The file /media/olly/Red_SSD/Kaggle_BC25/Data/Original_Data/birdclef-2025/train_audio/spepar1/iNat38721.ogg has a duration of 18.5 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
info = sf.info(fn)
print(f"Sample rate: {info.samplerate}")
print(f"Channels: {info.channels}")
print(f"Bit depth: {info.subtype}")  # This shows things like 'PCM_16', 'PCM_24'
# Out:
# Sample rate: 32000
# Channels: 1
# Bit depth: VORBIS

# %%
array, rate = load_file(fn)
array.shape
# Out:
# (592000,)

# %%
#sf.write("/home/olly/Desktop/example.ogg", array, rate)
import torch
audio_tensor = torch.unsqueeze(torch.from_numpy(array),0)
torchaudio.save("/home/olly/Desktop/example.ogg", audio_tensor, rate)

# %%
Audio("/home/olly/Desktop/example.ogg", rate=32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Determine crop positions
#
# - Only work with samples > 48 seconds
# - If no overlap with the 48 position, then crop at 48
# - If there is an overlap, crop at the top of that block of 12 seconds.
# - The lists for the remaining part must be reset by that amount, and it goes back into the cue

# %%
df_long = df_marked[df_marked['duration']> 48].copy()
df_long.head(40)
# Out:
#                 filename primary_label collection  \
# 0    528041/CSA36365.ogg        528041        CSA
# 1    528041/CSA36359.ogg        528041        CSA
# 2   1139490/CSA36385.ogg       1139490        CSA
# 3   1139490/CSA36389.ogg       1139490        CSA
# 4   1462711/CSA36371.ogg       1462711        CSA
# 5   1462711/CSA36379.ogg       1462711        CSA
# 6   1462711/CSA36390.ogg       1462711        CSA
# 7   1192948/CSA36358.ogg       1192948        CSA
# 8   1192948/CSA36366.ogg       1192948        CSA
# 9   1192948/CSA36373.ogg       1192948        CSA
# 10  1192948/CSA36388.ogg       1192948        CSA
# 11   963335/CSA36372.ogg        963335        CSA
# 12   963335/CSA36377.ogg        963335        CSA
# 13   963335/CSA36375.ogg        963335        CSA
# 14   963335/CSA36374.ogg        963335        CSA
# 15   963335/CSA36393.ogg        963335        CSA
# 16  1462737/CSA36341.ogg       1462737        CSA
# 17  1462737/CSA36369.ogg       1462737        CSA
# 18  1462737/CSA36380.ogg       1462737        CSA
# 19  1462737/CSA36381.ogg       1462737        CSA
# 20  1462737/CSA36391.ogg       1462737        CSA
# 21  1462737/CSA36386.ogg       1462737        CSA
# 22  1462737/CSA36395.ogg       1462737        CSA
# 23    48124/CSA36346.ogg         48124        CSA
# 24    52884/CSA36344.ogg         52884        CSA
# 25    52884/CSA36342.ogg         52884        CSA
# 27   476537/CSA35461.ogg        476537        CSA
# 28    64862/CSA18218.ogg         64862        CSA
# 29   476537/CSA35459.ogg        476537        CSA
# 30    64862/CSA18222.ogg         64862        CSA
# 31    24292/CSA34649.ogg         24292        CSA
# 32    24292/CSA34651.ogg         24292        CSA
# 33    24292/CSA35021.ogg         24292        CSA
# 37  1346504/CSA18803.ogg       1346504        CSA
# 38  1346504/CSA18791.ogg       1346504        CSA
# 39  1346504/CSA18793.ogg       1346504        CSA
# 47   715170/CSA34512.ogg        715170        CSA
# 48   715170/CSA34510.ogg        715170        CSA
# 49   715170/CSA35805.ogg        715170        CSA
# 50   715170/CSA35802.ogg        715170        CSA
#
#                                          author  \
# 0                             Fabio A. Sarria-S
# 1                             Fabio A. Sarria-S
# 2                             Fabio A. Sarria-S
# 3                             Fabio A. Sarria-S
# 4                             Fabio A. Sarria-S
# 5                             Fabio A. Sarria-S
# 6                             Fabio A. Sarria-S
# 7                             Fabio A. Sarria-S
# 8                             Fabio A. Sarria-S
# 9                             Fabio A. Sarria-S
# 10                            Fabio A. Sarria-S
# 11                            Fabio A. Sarria-S
# 12                            Fabio A. Sarria-S
# 13                            Fabio A. Sarria-S
# 14                            Fabio A. Sarria-S
# 15                            Fabio A. Sarria-S
# 16                            Fabio A. Sarria-S
# 17                            Fabio A. Sarria-S
# 18                            Fabio A. Sarria-S
# 19                            Fabio A. Sarria-S
# 20                            Fabio A. Sarria-S
# 21                            Fabio A. Sarria-S
# 22                            Fabio A. Sarria-S
# 23                            Fabio A. Sarria-S
# 24                            Fabio A. Sarria-S
# 25                            Fabio A. Sarria-S
# 27                         Eliana Barona-Cortés
# 28    Ana María Ospina-Larrea | Daniela Murillo
# 29  Eliana Barona-Cortés | Daniela García-Cobos
# 30    Ana María Ospina-Larrea | Daniela Murillo
# 31                        Eliana Barona- Cortés
# 32                        Eliana Barona- Cortés
# 33                    Alexandra Butrago-Cardona
# 37                       Orlando Acevedo-Charry
# 38                        Diego A Gómez-Morales
# 39                       Orlando Acevedo-Charry
# 47                      Angela M. Mendoza-Henao
# 48                      Angela M. Mendoza-Henao
# 49                      Angela M. Mendoza-Henao
# 50                      Angela M. Mendoza-Henao
#
#                        common_name     class secondary_labels    duration  \
# 0               Orophus conspersus   insecta             ['']  112.417563
# 1               Orophus conspersus   insecta             ['']  101.033469
# 2             Ragoniella pulchella   insecta             ['']   98.853375
# 3             Ragoniella pulchella   insecta             ['']   96.537719
# 4            Cocconotus aratifrons   insecta             ['']  107.817344
# 5            Cocconotus aratifrons   insecta             ['']   99.432906
# 6            Cocconotus aratifrons   insecta             ['']   98.302344
# 7            Oxyprora surinamensis   insecta             ['']  116.599812
# 8            Oxyprora surinamensis   insecta             ['']  105.446313
# 9            Oxyprora surinamensis   insecta             ['']  103.631469
# 10           Oxyprora surinamensis   insecta             ['']   96.072844
# 11               Subria sylvestris   insecta             ['']  108.242500
# 12               Subria sylvestris   insecta             ['']  107.488969
# 13               Subria sylvestris   insecta             ['']  106.700375
# 14               Subria sylvestris   insecta             ['']  103.571344
# 15               Subria sylvestris   insecta             ['']   97.343281
# 16          Docidocercus fasciatus   insecta             ['']  108.290844
# 17          Docidocercus fasciatus   insecta             ['']  106.155875
# 18          Docidocercus fasciatus   insecta             ['']  105.365625
# 19          Docidocercus fasciatus   insecta             ['']  103.985844
# 20          Docidocercus fasciatus   insecta             ['']  100.744375
# 21          Docidocercus fasciatus   insecta             ['']   99.418906
# 22          Docidocercus fasciatus   insecta             ['']   94.085813
# 23                        Katydids   insecta             ['']  137.421250
# 24                   True Crickets   insecta             ['']  166.263187
# 25                   True Crickets   insecta             ['']  124.098656
# 27            Colombian Plump Frog  amphibia             ['']  296.616000
# 28  Colombian Niputidea Nurse Frog  amphibia             ['']  292.488000
# 29            Colombian Plump Frog  amphibia             ['']  157.296000
# 30  Colombian Niputidea Nurse Frog  amphibia             ['']  100.416000
# 31       Caracas Snouted Tree Frog  amphibia             ['']  195.696000
# 32       Caracas Snouted Tree Frog  amphibia             ['']  145.488000
# 33       Caracas Snouted Tree Frog  amphibia             ['']  101.640000
# 37    Neoconocephalus brachypterus   insecta             ['']  107.914406
# 38    Neoconocephalus brachypterus   insecta             ['']   76.663687
# 39    Neoconocephalus brachypterus   insecta             ['']   66.994250
# 47                  Copris susanae   insecta             ['']  129.769375
# 48                  Copris susanae   insecta             ['']  124.418906
# 49                  Copris susanae   insecta             ['']  123.336062
# 50                  Copris susanae   insecta             ['']  115.716500
#
#                                                                               centres  \
# 0                                                                               [4.1]
# 1                                                                               [4.1]
# 2                                                                               [4.0]
# 3                                                                               [4.6]
# 4                                                                               [4.1]
# 5                                                                               [4.4]
# 6                                                                               [4.5]
# 7                                                                               [4.2]
# 8                                                                               [4.5]
# 9                                                                               [4.2]
# 10                                                                              [4.5]
# 11                                                                              [4.1]
# 12                                                                              [3.7]
# 13                                                                              [4.4]
# 14                                                                              [3.9]
# 15                                                                              [4.3]
# 16                                                                              [4.1]
# 17                                                                              [4.0]
# 18                                                                              [4.1]
# 19                                                                              [4.1]
# 20                                                                              [4.1]
# 21                                                                              [4.7]
# 22                                                                              [3.8]
# 23                                                                        [6.9, 19.1]
# 24                                                     [11.1, 23.2, 36.0, 46.2, 52.4]
# 25                                                                        [7.5, 12.7]
# 27                                                   [68.6, 83.9, 94.9, 111.2, 122.2]
# 28  [11.0, 16.7, 103.9, 115.3, 61.0, 126.1, 162.9, 218.1, 229.9, 238.9, 272.4, 282.3]
# 29                                          [5.4, 21.0, 33.9, 47.0, 61.9, 74.0, 80.4]
# 30                                                      [8.2, 19.2, 27.0, 81.3, 91.6]
# 31                     [9.6, 24.1, 37.7, 51.9, 60.7, 77.8, 88.8, 102.7, 115.6, 121.6]
# 32                                    [6.9, 21.0, 33.6, 45.1, 58.7, 70.2, 82.7, 89.5]
# 33                                                            [4.2, 14.3, 25.0, 31.3]
# 37                                          [6.5, 20.6, 34.7, 50.4, 64.9, 77.7, 85.2]
# 38                                                [6.1, 21.2, 33.1, 45.2, 57.8, 62.5]
# 39                                                                  [4.7, 14.4, 19.9]
# 47                                    [16.2, 5.3, 29.5, 41.3, 56.1, 69.1, 80.8, 89.2]
# 48                                          [5.1, 16.9, 30.3, 42.4, 55.3, 67.0, 72.5]
# 49                              [4.2, 15.2, 27.0, 38.1, 40.8, 50.8, 61.2, 70.3, 82.1]
# 50                                          [6.4, 16.7, 25.8, 37.2, 49.0, 59.3, 66.9]
#
#                 date_reviewed
# 0  2025-03-30 17:26:38.846914
# 1  2025-03-30 17:26:52.355833
# 2  2025-03-30 17:27:03.258653
# 3  2025-03-30 17:27:12.371260
# 4  2025-03-30 17:27:24.786244
# 5  2025-03-30 17:27:34.326689
# 6  2025-03-30 17:27:42.771245
# 7  2025-03-30 17:27:52.559547
# 8  2025-03-30 17:28:02.315068
# 9  2025-03-30 17:28:11.034505
# 10 2025-03-30 17:28:20.634143
# 11 2025-03-30 17:28:33.959255
# 12 2025-03-30 17:28:52.040864
# 13 2025-03-30 17:29:01.766015
# 14 2025-03-30 17:29:10.393663
# 15 2025-03-30 17:29:20.459062
# 16 2025-03-30 17:29:30.621424
# 17 2025-03-30 17:29:42.291556
# 18 2025-03-30 17:29:52.065511
# 19 2025-03-30 17:30:00.532412
# 20 2025-03-30 17:30:10.210220
# 21 2025-03-30 17:30:20.834067
# 22 2025-03-30 17:30:30.581672
# 23 2025-03-30 17:31:00.984259
# 24 2025-03-30 17:31:22.984939
# 25 2025-03-30 17:31:37.056318
# 27 2025-03-30 17:37:49.218288
# 28 2025-03-31 07:23:20.743984
# 29 2025-03-31 07:24:40.504696
# 30 2025-03-31 07:25:06.863470
# 31 2025-03-31 07:25:31.428272
# 32 2025-03-31 07:25:54.350423
# 33 2025-03-31 07:26:14.176656
# 37 2025-03-31 07:41:37.417271
# 38 2025-03-31 07:42:40.586453
# 39 2025-03-31 07:43:25.956882
# 47 2025-03-31 07:46:54.702687
# 48 2025-03-31 07:47:12.757967
# 49 2025-03-31 07:47:36.201859
# 50 2025-03-31 07:47:57.165363

# %%
df_long.shape
# Out:
# (5861, 10)

# %% [markdown]
# That's 5861 samples over 48 seconds long.  Breaking these into multiple samples will have quite a big impact on the training distribution.  Let's work with this sample from row 28 to come up with a suitable process.

# %%
row = df_long.iloc[28]
row
# Out:
# filename                                    476537/CSA35459.ogg
# primary_label                                            476537
# collection                                                  CSA
# author              Eliana Barona-Cortés | Daniela García-Cobos
# common_name                                Colombian Plump Frog
# class                                                  amphibia
# secondary_labels                                           ['']
# duration                                                157.296
# centres               [5.4, 21.0, 33.9, 47.0, 61.9, 74.0, 80.4]
# date_reviewed                        2025-03-31 07:24:40.504696
# Name: 29, dtype: object

# %%
centres = row['centres'].tolist()
duration = row['duration']
centres
# Out:
# [5.4, 21.0, 33.9, 47.0, 61.9, 74.0, 80.4]

# %%
duration
# Out:
# 157.296

# %%
[print(num) for num in range(0,120,20)]
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# [None, None, None, None, None, None]

# %%
default_length = 48
buffer = 6

def crop_with_centres(duration, centres, default_length, buffer):
    crop_centres = [c for c in centres if c < default_length - buffer]
    remaining_centres = [v for v in centres if v >= default_length - buffer]
    last_crop_centre = max(crop_centres, default=default_length - buffer)
    next_crop_centre = min(remaining_centres, default=default_length + buffer)
    crop_length = last_crop_centre + buffer
    new_centres = [round(c - next_crop_centre + buffer,2) for c in remaining_centres] #So the first should always = buffer
    new_duration = round(duration - crop_length,2)
    next_start = round(next_crop_centre - buffer,2)
    return next_start, crop_length, crop_centres, new_duration, new_centres


def split_row(row, default_length, buffer):
    #print(row['centres'])
    centres = row['centres'].tolist()
    duration = row['duration']

    crop_dict = {}
    counter = 0
    position = 0
    if isinstance(centres, list) and centres:
        while centres:
            next_start, crop_length, crop_centres,  duration, centres = crop_with_centres(duration, centres, default_length, buffer)
            new_fn = row['filename'].removesuffix(".ogg") + '_' + str(counter) + '.ogg'
            crop_dict[new_fn] = (position, crop_length, crop_centres)
            position = next_start
            counter +=1
    else:
        #do cropping uniformly, dict has None for the list
        for idx, start_time in enumerate(range(0, int(duration), default_length)):
            if duration - start_time > 2* buffer: #don't bother using anything less than 12 seconds
                new_fn = new_fn = row['filename'].removesuffix(".ogg") + '_' + str(idx) + '.ogg'
                length = default_length if duration - start_time > default_length else round(duration - start_time,1)
                crop_dict[new_fn] = (start_time, length, None)

    return crop_dict

crop_dicts = {}
for _, row in df_long.iterrows():
    orignal_fn = row['filename']
    crop_dict = split_row(row, default_length, buffer)
    crop_dicts[orignal_fn] = crop_dict

len(crop_dicts)
# Out:
# 5861

# %% [markdown]
# These were from the CSA collection, where there was only a short amount of usable sound at the beginning, but the segment was really long.  So it's correct

# %%
for idx, key in enumerate(crop_dicts):
    if idx < 5:
        print(crop_dicts[key])
# Out:
# {'528041/CSA36365_0.ogg': (0, 10.1, [4.1])}
# {'528041/CSA36359_0.ogg': (0, 10.1, [4.1])}
# {'1139490/CSA36385_0.ogg': (0, 10.0, [4.0])}
# {'1139490/CSA36389_0.ogg': (0, 10.6, [4.6])}
# {'1462711/CSA36371_0.ogg': (0, 10.1, [4.1])}

# %%
for idx, key in enumerate(crop_dicts):
    if 100 < idx < 105:
        print(crop_dicts[key])
# Out:
# {'52884/CSA35167_0.ogg': (0, 38.0, [8.0, 20.0, 32.0]), '52884/CSA35167_1.ogg': (38.0, 36.0, [6.0, 18.0, 30.0]), '52884/CSA35167_2.ogg': (36.0, 36.0, [6.0, 18.0, 30.0]), '52884/CSA35167_3.ogg': (36.0, 36.0, [6.0, 18.0, 30.0]), '52884/CSA35167_4.ogg': (36.0, 12.0, [6.0])}
# {'52884/CSA18799_0.ogg': (0, 44.1, [7.5, 19.5, 27.6, 38.1]), '52884/CSA18799_1.ogg': (63.4, 41.2, [6.0, 21.8, 35.2]), '52884/CSA18799_2.ogg': (61.9, 45.1, [6.0, 13.8, 24.7, 39.1]), '52884/CSA18799_3.ogg': (50.0, 12.0, [6.0])}
# {'52884/CSA35130_0.ogg': (0, 39.2, [9.2, 21.2, 33.2]), '52884/CSA35130_1.ogg': (39.2, 36.0, [6.0, 18.0, 30.0]), '52884/CSA35130_2.ogg': (36.0, 36.0, [6.0, 18.0, 30.0]), '52884/CSA35130_3.ogg': (36.0, 12.0, [6.0])}
# {'52884/CSA11080_0.ogg': (0, 46.7, [16.7, 28.7, 40.7]), '52884/CSA11080_1.ogg': (46.7, 36.0, [6.0, 18.0, 30.0]), '52884/CSA11080_2.ogg': (36.0, 36.0, [6.0, 18.0, 30.0]), '52884/CSA11080_3.ogg': (36.0, 36.0, [6.0, 18.0, 30.0])}

# %%
for idx, key in enumerate(crop_dicts):
    if 3000 < idx < 3005:
        print(crop_dicts[key])
# Out:
# {'yercac1/XC842227_0.ogg': (0, 48, None), 'yercac1/XC842227_1.ogg': (48, 48, None), 'yercac1/XC842227_2.ogg': (96, 48, None)}
# {'yercac1/XC122293_0.ogg': (0, 48, None), 'yercac1/XC122293_1.ogg': (48, 48, None), 'yercac1/XC122293_2.ogg': (96, 46.7, None)}
# {'yercac1/XC129007_0.ogg': (0, 48, None), 'yercac1/XC129007_1.ogg': (48, 48, None), 'yercac1/XC129007_2.ogg': (96, 41.8, None)}
# {'yercac1/XC59783_0.ogg': (0, 48, None), 'yercac1/XC59783_1.ogg': (48, 48, None), 'yercac1/XC59783_2.ogg': (96, 38.9, None)}

# %%
for idx, key in enumerate(crop_dicts):
    if idx > 5856:
        print(crop_dicts[key])
# Out:
# {'grekis/XC806345_0.ogg': (0, 48, None)}
# {'grekis/iNat926084_0.ogg': (0, 48, None)}
# {'grekis/XC518343_0.ogg': (0, 48, None)}
# {'grekis/XC317696_0.ogg': (0, 48, None)}

# %% [markdown]
# ## Modify the labels dataframe

# %%
def process_row(row, crop_dict):
    rows = []
    for crop_fn in crop_dict:
        new_row = row.copy()  # important! don't modify the original
        new_row['start_position'] = crop_dict[crop_fn][0]
        new_row['duration'] = crop_dict[crop_fn][1]
        new_row['centres'] = crop_dict[crop_fn][2]
        new_row['original_file'] = row['filename']
        new_row['filename'] = crop_fn
        rows.append(new_row)

    return rows

new_rows = []
for _, row in df_long.iterrows():
    orignal_fn = row['filename']
    crops = crop_dicts[orignal_fn]
    replacements = process_row(row, crops)  # returns list of pd.Series
    new_rows.extend(replacements)

new_df = pd.DataFrame(new_rows)
new_df.head()
# Out:
#                  filename primary_label collection             author  \
# 0   528041/CSA36365_0.ogg        528041        CSA  Fabio A. Sarria-S
# 1   528041/CSA36359_0.ogg        528041        CSA  Fabio A. Sarria-S
# 2  1139490/CSA36385_0.ogg       1139490        CSA  Fabio A. Sarria-S
# 3  1139490/CSA36389_0.ogg       1139490        CSA  Fabio A. Sarria-S
# 4  1462711/CSA36371_0.ogg       1462711        CSA  Fabio A. Sarria-S
#
#              common_name    class secondary_labels  duration centres  \
# 0     Orophus conspersus  insecta             ['']      10.1   [4.1]
# 1     Orophus conspersus  insecta             ['']      10.1   [4.1]
# 2   Ragoniella pulchella  insecta             ['']      10.0   [4.0]
# 3   Ragoniella pulchella  insecta             ['']      10.6   [4.6]
# 4  Cocconotus aratifrons  insecta             ['']      10.1   [4.1]
#
#                date_reviewed  start_position         original_file
# 0 2025-03-30 17:26:38.846914             0.0   528041/CSA36365.ogg
# 1 2025-03-30 17:26:52.355833             0.0   528041/CSA36359.ogg
# 2 2025-03-30 17:27:03.258653             0.0  1139490/CSA36385.ogg
# 3 2025-03-30 17:27:12.371260             0.0  1139490/CSA36389.ogg
# 4 2025-03-30 17:27:24.786244             0.0  1462711/CSA36371.ogg

# %%
new_df.iloc[1000:1015]
# Out:
#                       filename primary_label collection  \
# 1166    crbtan1/XC236091_1.ogg       crbtan1         XC
# 1166    crbtan1/XC236091_2.ogg       crbtan1         XC
# 1167    crbtan1/XC373218_0.ogg       crbtan1         XC
# 1167    crbtan1/XC373218_1.ogg       crbtan1         XC
# 1168    labter1/XC384529_0.ogg       labter1         XC
# 1168    labter1/XC384529_1.ogg       labter1         XC
# 1169    labter1/XC186487_0.ogg       labter1         XC
# 1169    labter1/XC186487_1.ogg       labter1         XC
# 1170    labter1/XC356722_0.ogg       labter1         XC
# 1170    labter1/XC356722_1.ogg       labter1         XC
# 1171    crbtan1/XC368718_0.ogg       crbtan1         XC
# 1171    crbtan1/XC368718_1.ogg       crbtan1         XC
# 1172    crbtan1/XC542259_0.ogg       crbtan1         XC
# 1172    crbtan1/XC542259_1.ogg       crbtan1         XC
# 1173  labter1/iNat790583_0.ogg       labter1       iNat
#
#                       author             common_name class  \
# 1166            Niels Krabbe  Crimson-backed Tanager  aves
# 1166            Niels Krabbe  Crimson-backed Tanager  aves
# 1167            Kent Livezey  Crimson-backed Tanager  aves
# 1167            Kent Livezey  Crimson-backed Tanager  aves
# 1168             Jan Cubilla       Large-billed Tern  aves
# 1168             Jan Cubilla       Large-billed Tern  aves
# 1169               João Gava       Large-billed Tern  aves
# 1169               João Gava       Large-billed Tern  aves
# 1170     Miguel Angel Torres       Large-billed Tern  aves
# 1170     Miguel Angel Torres       Large-billed Tern  aves
# 1171            Kent Livezey  Crimson-backed Tanager  aves
# 1171            Kent Livezey  Crimson-backed Tanager  aves
# 1172            Kent Livezey  Crimson-backed Tanager  aves
# 1172            Kent Livezey  Crimson-backed Tanager  aves
# 1173  Eduardo Luis Beltrocco       Large-billed Tern  aves
#
#                        secondary_labels  duration                  centres  \
# 1166                               ['']      36.0        [6.0, 18.0, 30.0]
# 1166                               ['']      18.1              [6.0, 12.1]
# 1167                               ['']      42.3  [2.2, 12.3, 24.3, 36.3]
# 1167                               ['']      39.2        [6.0, 18.0, 33.2]
# 1168                               ['']      36.8        [6.8, 18.8, 30.8]
# 1168                               ['']      43.4  [6.0, 18.0, 30.0, 37.4]
# 1169                               ['']      46.8  [4.8, 16.8, 28.8, 40.8]
# 1169                               ['']      24.0              [6.0, 18.0]
# 1170                               ['']      47.1  [5.1, 17.1, 29.1, 41.1]
# 1170                               ['']      19.4              [6.0, 13.4]
# 1171                        ['strfly1']      45.6  [3.6, 15.6, 27.6, 39.6]
# 1171                        ['strfly1']      19.8              [6.0, 13.8]
# 1172  ['cregua1', 'rumfly1', 'cocwoo1']      46.9  [4.9, 16.9, 28.9, 40.9]
# 1172  ['cregua1', 'rumfly1', 'cocwoo1']      17.3              [6.0, 11.3]
# 1173                               ['']      45.7  [3.7, 15.7, 27.7, 39.7]
#
#                   date_reviewed  start_position           original_file
# 1166 2025-04-01 07:39:09.965107            45.6    crbtan1/XC236091.ogg
# 1166 2025-04-01 07:39:09.965107            36.0    crbtan1/XC236091.ogg
# 1167 2025-04-01 07:39:40.670814             0.0    crbtan1/XC373218.ogg
# 1167 2025-04-01 07:39:40.670814            42.3    crbtan1/XC373218.ogg
# 1168 2025-04-01 07:39:57.817478             0.0    labter1/XC384529.ogg
# 1168 2025-04-01 07:39:57.817478            36.8    labter1/XC384529.ogg
# 1169 2025-04-01 07:40:09.450959             0.0    labter1/XC186487.ogg
# 1169 2025-04-01 07:40:09.450959            46.8    labter1/XC186487.ogg
# 1170 2025-04-01 07:40:24.900409             0.0    labter1/XC356722.ogg
# 1170 2025-04-01 07:40:24.900409            47.1    labter1/XC356722.ogg
# 1171 2025-04-01 07:40:37.468723             0.0    crbtan1/XC368718.ogg
# 1171 2025-04-01 07:40:37.468723            45.6    crbtan1/XC368718.ogg
# 1172 2025-04-01 07:40:52.246432             0.0    crbtan1/XC542259.ogg
# 1172 2025-04-01 07:40:52.246432            46.9    crbtan1/XC542259.ogg
# 1173 2025-04-01 07:41:05.849503             0.0  labter1/iNat790583.ogg

# %% [markdown]
# ## Validate Metadata

# %%
non_numeric_values = {}
columns_to_check = ['duration', 'start_position']
for col in columns_to_check:
    numeric_values = pd.to_numeric(new_df[col], errors='coerce')
    non_numeric_values[col] = new_df[numeric_values.isna()]

for col, non_numeric_df in non_numeric_values.items():
    if len(non_numeric_df) != 0:
        print(f"Non-numeric values in {col}:")
        print(non_numeric_df)
    else:
        print(Go.S + f'There are no non-numeric values in {col}' + Go.E)
# Out:
# There are no non-numeric values in duration
# There are no non-numeric values in start_position

# %%
new_df.describe()
# Out:
#            duration                  date_reviewed  start_position
# count  14156.000000                           4422    14156.000000
# mean      39.639771  2025-04-02 18:35:38.755640064       52.351556
# min        8.400000     2025-03-30 17:26:38.846914        0.000000
# 25%       36.000000  2025-04-01 09:12:57.903235072        0.000000
# 50%       48.000000  2025-04-02 15:40:46.719691008       36.000000
# 75%       48.000000  2025-04-03 20:04:07.631607040       48.000000
# max       48.000000     2025-04-06 10:44:38.913199     1728.000000
# std       11.602878                            NaN      106.635509

# %% [markdown]
# ## Crop and save the new files

# %%
paths.MODIFIED_AUDIO
# Out:
# PosixPath('/media/olly/Red_SSD/Kaggle_BC25/Data/Cropped_Train_Audio')

# %%
unique_labels = sorted(list(df['primary_label'].unique()))
for bird_e_name in unique_labels:
    sub_folder_path = paths.MODIFIED_AUDIO / bird_e_name
    sub_folder_path.mkdir(exist_ok=True)

# %%
def process_clip(item_tuple, 
                 in_folder = paths.ORIGINAL_AUDIO,
                 out_folder = paths.MODIFIED_AUDIO,
                 default_sr = cfg.SR):
    rel_path, df = item_tuple
    in_path = str(in_folder / rel_path)

    #print(in_path)
    y, sr = load_file(in_path)

    df['start'] = (df['start_position'] * sr).astype(int)
    df['end'] = (df['start'] + df['duration'] * sr).astype(int)

    if y is not None:
        for _, row in df.iterrows():
            start=row.start
            end = row.end
            if end > len(y):
                end = len(y)
            part = y[start:end]
            if len(part) >=1:
                out_path = str(out_folder / row.filename)
                if sr != default_sr:
                    num_samples = int(len(part) * default_sr / sr)
                    part = resample(part, num_samples)
                sf.write(out_path, part, default_sr)
    return

# %%
if cfg.SAVE_SOUNDFILES:
   grouped_df = new_df.groupby('original_file')
   Parallel(n_jobs=6)(delayed(process_clip)(group) for group in tqdm(grouped_df))

# %% [markdown]
# Let's remove any samples from the dataframe that for any reason didn't get saved to their expected locations

# %%
if cfg.SAVE_SOUNDFILES:
    original_length = len(new_df)
    training_samples = set([path.parent.name + '/' + path.name for path in Path(paths.MODIFIED_AUDIO).rglob('*') if path.suffix in {'.ogg', '.flac'}])

    new_df = new_df[new_df['filename'].isin(training_samples)]
    new_length = len(new_df)

    print(Blue.S + 'The original length was: ' +Blue.E, original_length)
    print(Blue.S + 'The final length was: ' +Blue.E, new_length)
    if original_length > new_length:
        print(Blue.S + 'Samples removed: ' + Blue.E, original_length - new_length)

# %% [markdown]
# Finally reshape the dataframe for training.  Keep the original filename in case I want to use this for split selection.

# %%
df_out = new_df[['filename', 'primary_label', 'secondary_labels', 'class', 'centres', 'original_file']]
df_out.head()
# Out:
#                  filename primary_label secondary_labels    class centres  \
# 0   528041/CSA36365_0.ogg        528041             ['']  insecta   [4.1]
# 1   528041/CSA36359_0.ogg        528041             ['']  insecta   [4.1]
# 2  1139490/CSA36385_0.ogg       1139490             ['']  insecta   [4.0]
# 3  1139490/CSA36389_0.ogg       1139490             ['']  insecta   [4.6]
# 4  1462711/CSA36371_0.ogg       1462711             ['']  insecta   [4.1]
#
#           original_file
# 0   528041/CSA36365.ogg
# 1   528041/CSA36359.ogg
# 2  1139490/CSA36385.ogg
# 3  1139490/CSA36389.ogg
# 4  1462711/CSA36371.ogg

# %%
df_out.to_parquet(paths.CROP_LABELS_PATH, index=False)

# %%
df_check = pd.read_parquet(paths.CROP_LABELS_PATH, engine="pyarrow")
df_check.head()
# Out:
#                  filename primary_label secondary_labels    class centres  \
# 0   528041/CSA36365_0.ogg        528041             ['']  insecta   [4.1]
# 1   528041/CSA36359_0.ogg        528041             ['']  insecta   [4.1]
# 2  1139490/CSA36385_0.ogg       1139490             ['']  insecta   [4.0]
# 3  1139490/CSA36389_0.ogg       1139490             ['']  insecta   [4.6]
# 4  1462711/CSA36371_0.ogg       1462711             ['']  insecta   [4.1]
#
#           original_file
# 0   528041/CSA36365.ogg
# 1   528041/CSA36359.ogg
# 2  1139490/CSA36385.ogg
# 3  1139490/CSA36389.ogg
# 4  1462711/CSA36371.ogg

# %%
df_check.shape
# Out:
# (14156, 6)
