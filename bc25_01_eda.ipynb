# %% [markdown]
# # Data Exploration & Preprocessing
#
# ### Observations
#
# ### Data Preprocessing Steps
# - Combine the three datasets into a single `.csv` with the dataset folder in the file path
# - create an output `.json` file with Common Name & Scientific Name using ebird code as the key
# - Remove any unwanted labels, such as 'spybird' from the secondaries, or anything not in the primaries

# %%
use_case = {
            'experiment' : 1,
            'project_root': '/home/olly/Desktop/Kaggle_BC25',
            #'project_root': r'C:\Users\ollyp\OneDrive\Desktop\Kaggle_BC25'
            #'project_root': '/media/olly/Red_SSD/Kaggle_BC25',
            }

# %%
from pathlib import Path
import pandas as pd
import plotly.express as px
from joblib import Parallel, delayed
import json
from tqdm.notebook import tqdm
from collections import Counter
from IPython.display import Audio
import ast
import torchaudio
import torch
import numpy as np

# %%
class FilePaths:
    def __init__(self, options=None):
        _project_dir = Path(options['project_root'])
        self.DATA_FOLDER = _project_dir / 'Data'
        self.IMAGE_FOLDER = self.DATA_FOLDER / 'Original_Data' / 'birdclef-2025' / 'train_audio'
        self.KAGGLE_DS = self.DATA_FOLDER / 'Train_Xeno_Canto'
        self.EXTRA_DATA = self.DATA_FOLDER / 'Extra_Samples' / 'metadata.csv'
        self.METADATA = self.DATA_FOLDER /  'Original_Data' / 'birdclef-2025' / 'train.csv'
        self.OUTPUT_CSV_PATH = self.DATA_FOLDER / 'Train_Metadata/train.csv'
        self.OUTPUT_NAMING_CSV_PATH = self.DATA_FOLDER / 'Train_Metadata/naming.csv'
        self.OUTPUT_JSON_PATH = self.DATA_FOLDER / 'Train_Metadata/species_names.json'
        self.OUTPUT_AUX_LABELS_PATH = self.DATA_FOLDER / 'Train_Metadata' / 'aux_labels.parquet'

paths = FilePaths(options=use_case)

# %% [markdown]
# Now I'm going to extract these configuration settings to variables for the rest of the script.  Doing it this way to make it consistancy with the rest of the project, and so that the analysis can be updated for any changes in dataset settings.

# %%
#use_cols = ['filename', 'primary_label', 'secondary_labels', 'start', 'end', 'source_fn']
df = pd.read_csv(paths.METADATA)
df['filepath'] = str(paths.IMAGE_FOLDER) + '/' + df['filename'] 
print(f'There are {len(df)} rows')
df.head(3)
# Out:
# There are 28564 rows
#   primary_label secondary_labels  type              filename collection  \
# 0       1139490             ['']  ['']  1139490/CSA36385.ogg        CSA
# 1       1139490             ['']  ['']  1139490/CSA36389.ogg        CSA
# 2       1192948             ['']  ['']  1192948/CSA36358.ogg        CSA
#
#    rating                                                url  latitude  \
# 0     0.0  http://colecciones.humboldt.org.co/rec/sonidos...    7.3206
# 1     0.0  http://colecciones.humboldt.org.co/rec/sonidos...    7.3206
# 2     0.0  http://colecciones.humboldt.org.co/rec/sonidos...    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#            license                                           filepath
# 0  cc-by-nc-sa 4.0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 1  cc-by-nc-sa 4.0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 2  cc-by-nc-sa 4.0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...

# %%
use_cols = ['primary_label', 'secondary_labels', 'filename', 'collection', 'latitude',
            'longitude', 'scientific_name', 'common_name', 'author', 'filepath']
df = df[use_cols]
df.head(3)
# Out:
#   primary_label secondary_labels              filename collection  latitude  \
# 0       1139490             ['']  1139490/CSA36385.ogg        CSA    7.3206
# 1       1139490             ['']  1139490/CSA36389.ogg        CSA    7.3206
# 2       1192948             ['']  1192948/CSA36358.ogg        CSA    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#                                             filepath
# 0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 1  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 2  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...

# %% [markdown]
# Let's add another column for the taxonomic class

# %%
df[df['common_name'].str.contains('Daedadelus', case=False, na=False)]  
df[df['scientific_name'].str.contains('Daedadelus waehnerorum', case=False, na=False)]
# Out:
#    primary_label secondary_labels              filename collection  latitude  \
# 44       1564122             ['']  1564122/CSA34195.ogg        CSA   -3.8333
# 45       1564122             ['']  1564122/CSA34196.ogg        CSA   -3.8333
# 46       1564122             ['']  1564122/CSA34197.ogg        CSA   -3.8333
# 47       1564122             ['']  1564122/CSA34198.ogg        CSA   -3.8333
# 48       1564122             ['']  1564122/CSA34199.ogg        CSA   -3.8333
# 49       1564122             ['']  1564122/CSA34200.ogg        CSA   -3.8333
#
#     longitude          scientific_name              common_name  \
# 44   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
# 45   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
# 46   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
# 47   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
# 48   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
# 49   -70.3333  Daedadelus waehnerorum   Daedadelus waehnerorum
#
#                     author                                           filepath
# 44  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 45  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 46  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 47  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 48  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...
# 49  Fernando Montealegre-Z  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...

# %%
num_classes = len(list(df['primary_label'].unique()))
num_classes
# Out:
# 206

# %%
class_mapping = {'amphibia':["Spotted Foam-nest Frog", "Emerald Glass Frog","Andean Poison Frog",
                            "Common Rocket Frog","Yellow-striped Poison Dart Frog","Spotted-thighed Poison Frog",
                            "Lesser Antillean whistling frog","Whistling Grass Frog","Mexican White-lipped Frog",
                            "Masked Tree Frog","Caracas Snouted Tree Frog","Red Snouted Tree Frog","Colombian Plump Frog",
                            "Panama Humming Frog","Giant Toad","Copiphora gracilis","Rusty Tree Frog",
                            "Chirique-Flusse Tree Frog","Colombian Niputidea Nurse Frog","Bogert's Aquatic Tree Frog",
                            "Boettger's Colombian Tree Frog","Harlequin Treefrog","Yellow Tree Frog","Esmereldas Robber Frog",
                            "Túngara Frog","Tatayo's Glass Frog","Savage's Thin-toed Frog","Vaillant's Frog",
                            "Cachabi Robber Frog","Bogota Robber Frog","Banded Rain Frog","Palm Rocket Frog",
                            "Veined Tree Frog",'Santa Rita Rocket Frog',"Rivero's Toad"
                            ],
                 'aves':['Amazon Kingfisher','American Kestrel','American Pygmy Kingfisher',
                         'Anhinga','Bay-breasted Warbler','Bare-faced Ibis','Bananaquit',
                         'Blue-and-yellow Macaw','Black-bellied Whistling-Duck','Bicolored Wren',
                         'Black-capped Donacobius','Yellow-throated Toucan','Blue-black Grassquit',
                         'Black-bellied Wren','Black-crested Antshrike','Black-collared Hawk',
                         'Black-chested Jay','Black-crowned Tityra','Blue-headed Parrot','Black Vulture',
                         'Boat-billed Flycatcher','Boat-billed Heron', 'Brown-throated Parakeet',
                         'Blue-billed Curassow','Buff-breasted Wren','Whooping Motmot','Blue-gray Tanager',
                         'Buff-throated Saltator','Carib Grackle','Cattle Tyrant','Chestnut-backed Antbird',
                         'Chestnut-fronted Macaw', 'Cinnamon Becard', 'Cocoi Heron', 'Cocoa Woodcreeper',
                         'Collared Aracari', 'Colombian Chachalaca', 'Common Pauraque', 'Common Potoo', 
                         'Common Tody-Flycatcher', 'Crimson-backed Tanager', 'Crimson-crested Woodpecker',
                         'Crested Bobwhite', 'Crested Guan', 'Crested Oropendola', 'Eared Dove',
                         'Fork-tailed Flycatcher', 'Golden-headed Manakin', 'Olivaceous Saltator',
                         'Great Black Hawk', 'Greater Ani', 'Great Egret', 'Green Ibis', 'Great Kiskadee',
                         'Great Potoo', 'Great Tinamou', 'Green Kingfisher', 'Gray Seedeater', 'Gray-breasted Martin',
                         'Gray-cowled Wood-Rail', 'Large-billed Tern', 'Laughing Falcon', 'Least Grebe',
                         'Lineated Woodpecker', 'Little Tinamou', 'Masked Tityra', 'Neotropic Cormorant',
                         'Northern Screamer', 'Olivaceous Piculet', 'Orange-chinned Parakeet',
                         'Pale-legged Hornero', 'Palm Tanager', 'Pale-vented Pigeon', 'Pied Puffbird',
                         'Piratic Flycatcher', 'Pied Water-Tyrant', 'Plain-brown Woodcreeper',
                         'Plain-colored Tanager', 'Plumbeous Kite', 'Purple Gallinule', 'Red-and-green Macaw',
                         'Red-breasted Meadowlark', 'Red-crowned Woodpecker', 'Ringed Kingfisher', 'Roadside Hawk',
                         'Roseate Spoonbill', 'Royal Flycatcher', 'Rufous-tailed Hummingbird', 'Ruddy-breasted Seedeater',
                         'Rufous Motmot', 'Ruddy Ground Dove', 'Rusty-margined Flycatcher', 'Rufescent Tiger-Heron',
                         'Rufous-tailed Jacamar', 'Russet-throated Puffbird', 'Saffron Finch', 'Saffron-headed Parrot',
                         'Savanna Hawk', 'Sepia-capped Flycatcher', 'Shining-green Hummingbird', 'Slate-headed Tody-Flycatcher',
                         'Smooth-billed Ani', 'Snowy Egret', 'Southern Beardless-Tyrannulet', 'Social Flycatcher',
                         'Solitary Sandpiper', 'Southern Lapwing', 'Spot-breasted Woodpecker', 'Spectacled Owl',
                         'Spectacled Parrotlet', 'Southern Rough-winged Swallow', 'Straight-billed Woodcreeper',
                         'Striped Cuckoo', 'Streaked Flycatcher', 'Striated Heron', 'Striped Owl', 'Thick-billed Seed-Finch',
                         'Thick-billed Euphonia', 'Brown-winged Schiffornis', 'Tropical Kingbird', 'Tropical Parula',
                         'Tropical Screech-Owl', 'Turkey Vulture', 'Vermilion Flycatcher', 'Wattled Jacana',
                         'White-breasted Wood-Wren', 'White-bellied Antbird', 'White-bearded Manakin',
                         'White-fringed Antwren', 'White-headed Marsh Tyrant', 'White-tipped Dove',
                         'White-tailed Trogon', 'White-winged Swallow', 'Wood Stork', 'Crested Caracara',
                         'Yellow-bellied Elaenia', 'Yellow-breasted Flycatcher', 'Yellow-bellied Seedeater',
                         'Yellow-chinned Spinetail', 'Yellow-crowned Tyrannulet', 'Yellow-hooded Blackbird',
                         'Yellow-headed Caracara', 'Yellow Oriole', 'Yellow-olive Flycatcher', 'Yellow-rumped Cacique',
                         'Yellow-crowned Parrot'
                         ],
                 'insecta':['Ragoniella pulchella', 'Oxyprora surinamensis', 'Copiphora colombiae',
                            'Cocconotus aratifrons', 'Neoconocephalus brachypterus', 'Katydids',
                            'Typical Cicadas', 'Eschatoceras bipunctatus', 'Orophus conspersus',
                            'Panoploscelis specularis', 'True Crickets', 'Subria sylvestris', 
                            'Typophyllum inflatum', 'Daedadelus waehnerorum', 'Copris susanae','Docidocercus fasciatus'
                            ],
                 'mamalia':['Common Raccoon', 'Neotropical River Otter','Jaguar','Mountain Lion','Crab-eating Fox',
                            'Collared Peccary','Red-tailed Squirrel','Brown-throated Three-toed Sloth','Colombian Red Howler Monkey'
                            ]
                }

# %%
num_classes = sum([len(value) for value in class_mapping.values()])
num_classes
# Out:
# 206

# %%
common_names = {item for sublist in class_mapping.values() for item in sublist}
missing = set(df['common_name'].unique()) - common_names
missing
# Out:
# {'Daedadelus waehnerorum '}

# %%
#inverse_map = {value:key for value, key in dict_list for dict_list, key in class_mapping.items()}
inverse_map = {value: key for key, values in class_mapping.items() for value in values}
inverse_map['Daedadelus waehnerorum '] = 'insecta'
df['class'] = df['common_name'].map(inverse_map)
df.head()
# Out:
#   primary_label secondary_labels              filename collection  latitude  \
# 0       1139490             ['']  1139490/CSA36385.ogg        CSA    7.3206
# 1       1139490             ['']  1139490/CSA36389.ogg        CSA    7.3206
# 2       1192948             ['']  1192948/CSA36358.ogg        CSA    7.3791
# 3       1192948             ['']  1192948/CSA36366.ogg        CSA    7.2800
# 4       1192948             ['']  1192948/CSA36373.ogg        CSA    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 3   -73.8582  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 4   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#                                             filepath    class
# 0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 1  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 2  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 3  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 4  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta

# %%
df['collection'].unique()
# Out:
# array(['CSA', 'XC', 'iNat'], dtype=object)

# %%
print(f'There are {len(df)} rows in the train dataframe')
# Out:
# There are 28564 rows in the train dataframe

# %%
df_names = df.drop_duplicates(subset='primary_label', keep='first')[['primary_label', 'common_name', 'scientific_name', 'class']].sort_values(by='primary_label')
df_names.head(3)
# Out:
#   primary_label            common_name        scientific_name    class
# 0       1139490   Ragoniella pulchella   Ragoniella pulchella  insecta
# 2       1192948  Oxyprora surinamensis  Oxyprora surinamensis  insecta
# 6       1194042    Copiphora colombiae    Copiphora colombiae  insecta

# %%
df_names.tail(3)
# Out:
#       primary_label              common_name           scientific_name class
# 27595       yeofly1  Yellow-olive Flycatcher  Tolmomyias sulphurescens  aves
# 28120       yercac1    Yellow-rumped Cacique              Cacicus cela  aves
# 28422        ywcpar    Yellow-crowned Parrot      Amazona ochrocephala  aves

# %% [markdown]
# Let's save this out to CSV, but in the format that matches my BirdNamer class

# %%
naming_dict = {'primary_label':'eBird', 'common_name':'CommonName', 'scientific_name': 'ScientificName', 'class':'Class'}

df_names.rename(columns=naming_dict, inplace=True)
df_names.head()
# Out:
#       eBird                    CommonName                ScientificName  \
# 0   1139490          Ragoniella pulchella          Ragoniella pulchella
# 2   1192948         Oxyprora surinamensis         Oxyprora surinamensis
# 6   1194042           Copiphora colombiae           Copiphora colombiae
# 9    126247        Spotted Foam-nest Frog       Leptodactylus insularum
# 15  1346504  Neoconocephalus brachypterus  Neoconocephalus brachypterus
#
#        Class
# 0    insecta
# 2    insecta
# 6    insecta
# 9   amphibia
# 15   insecta

# %%
df_names.to_csv(paths.OUTPUT_NAMING_CSV_PATH, index=False)

# %%
def plot_class_distribution(df, plot_col='primary_label', title='primary_label frequency', height=400):
    total_counts = df[plot_col].value_counts().reset_index()
    total_counts.columns = [plot_col, 'total_count']
    fig = px.bar(total_counts, x=total_counts[plot_col], log_y=True, y=total_counts.total_count, template='seaborn',
    hover_data=[plot_col, 'total_count'], color=plot_col, height=height)
    fig.update_layout(title=title)
    fig.update_layout(showlegend=False)
    fig.update_xaxes(categoryorder='total descending')
    fig.show()

plot_class_distribution(df, plot_col='primary_label', title='Frequency by primary_label')

# %%
total_counts = df['primary_label'].value_counts().reset_index()
total_counts.columns = ['primary_label', 'total_count']
total_counts.sort_values('total_count', ascending=True)
total_counts.tail(50)
# Out:
#     primary_label  total_count
# 156       rutpuf1           17
# 157         65344           16
# 158         65349           16
# 159       shghum1           15
# 160         41970           15
# 161       sahpar1           14
# 162         67252           14
# 163       norscr1           14
# 164         24322           13
# 165        turvul           11
# 166        135045           10
# 167       1462737            7
# 168        787625            7
# 169         65547            7
# 170        126247            6
# 171        555142            6
# 172         24272            6
# 173       1564122            6
# 174       plctan1            6
# 175         65336            6
# 176       1346504            5
# 177        548639            5
# 178        476538            5
# 179        963335            5
# 180         66893            5
# 181        714022            5
# 182         46010            5
# 183        134933            4
# 184       1192948            4
# 185        868458            4
# 186        523060            4
# 187         65419            3
# 188       1194042            3
# 189       1462711            3
# 190         24292            3
# 191         66531            2
# 192         21116            2
# 193         66578            2
# 194         42113            2
# 195         21038            2
# 196         47067            2
# 197         66016            2
# 198        528041            2
# 199        476537            2
# 200         67082            2
# 201         64862            2
# 202         81930            2
# 203         41778            2
# 204         42087            2
# 205       1139490            2

# %%
total_counts.to_csv(paths.DATA_FOLDER / 'primary_label_counts.csv')

# %%
plot_class_distribution(df[df['class']=='aves'], plot_col='primary_label', title='Bird Label Counts')

# %%
plot_class_distribution(df[df['class']=='insecta'], plot_col='primary_label', title='Insecta Label Counts')

# %%
plot_class_distribution(df[df['class']=='amphibia'], plot_col='common_name', title='Amphibia Label Counts')

# %%
plot_class_distribution(df[df['class']=='mamalia'], plot_col='common_name', title='Mammalia Label Counts')

# %%
df_names.to_csv(paths.OUTPUT_NAMING_CSV_PATH, index=False)
result_list = df_names.to_dict(orient='records')

with paths.OUTPUT_JSON_PATH.open('w') as file:
    json.dump(result_list, file, indent=4)

# %%
total_counts_primary = df['common_name'].value_counts().reset_index()
total_counts_primary.tail(10)
# Out:
#                          common_name  count
# 196  Brown-throated Three-toed Sloth      2
# 197                  Vaillant's Frog      2
# 198               Orophus conspersus      2
# 199             Colombian Plump Frog      2
# 200                 Palm Rocket Frog      2
# 201   Colombian Niputidea Nurse Frog      2
# 202                    Rivero's Toad      2
# 203          Neotropical River Otter      2
# 204                  Crab-eating Fox      2
# 205             Ragoniella pulchella      2

# %% [markdown]
# ## Get the lengths of each sample

# %%
df.head()
# Out:
#   primary_label secondary_labels              filename collection  latitude  \
# 0       1139490             ['']  1139490/CSA36385.ogg        CSA    7.3206
# 1       1139490             ['']  1139490/CSA36389.ogg        CSA    7.3206
# 2       1192948             ['']  1192948/CSA36358.ogg        CSA    7.3791
# 3       1192948             ['']  1192948/CSA36366.ogg        CSA    7.2800
# 4       1192948             ['']  1192948/CSA36373.ogg        CSA    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 3   -73.8582  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 4   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#                                             filepath    class
# 0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 1  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 2  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 3  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta
# 4  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta

# %%
def get_audio_duration(filepath):
    info = torchaudio.info(filepath)
    return info.num_frames / info.sample_rate  # Duration in seconds

filepaths = df['filepath'].to_list()

df["duration"] = Parallel(n_jobs=4)(
    delayed(get_audio_duration)(fp) for fp in tqdm(filepaths)
)
# Out:
#   0%|          | 0/28564 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#   primary_label secondary_labels              filename collection  latitude  \
# 0       1139490             ['']  1139490/CSA36385.ogg        CSA    7.3206
# 1       1139490             ['']  1139490/CSA36389.ogg        CSA    7.3206
# 2       1192948             ['']  1192948/CSA36358.ogg        CSA    7.3791
# 3       1192948             ['']  1192948/CSA36366.ogg        CSA    7.2800
# 4       1192948             ['']  1192948/CSA36373.ogg        CSA    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 3   -73.8582  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 4   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#                                             filepath    class    duration
# 0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta   98.853375
# 1  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta   96.537719
# 2  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  116.599812
# 3  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  105.446313
# 4  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  103.631469

# %%
df_aux = df[['filename', 'primary_label',  'collection', 'author', 'common_name', 'class', 'secondary_labels', 'duration']]
df_aux.head()
# Out:
#                filename primary_label collection             author  \
# 0  1139490/CSA36385.ogg       1139490        CSA  Fabio A. Sarria-S
# 1  1139490/CSA36389.ogg       1139490        CSA  Fabio A. Sarria-S
# 2  1192948/CSA36358.ogg       1192948        CSA  Fabio A. Sarria-S
# 3  1192948/CSA36366.ogg       1192948        CSA  Fabio A. Sarria-S
# 4  1192948/CSA36373.ogg       1192948        CSA  Fabio A. Sarria-S
#
#              common_name    class secondary_labels    duration
# 0   Ragoniella pulchella  insecta             ['']   98.853375
# 1   Ragoniella pulchella  insecta             ['']   96.537719
# 2  Oxyprora surinamensis  insecta             ['']  116.599812
# 3  Oxyprora surinamensis  insecta             ['']  105.446313
# 4  Oxyprora surinamensis  insecta             ['']  103.631469

# %%
df_aux.to_parquet(paths.OUTPUT_AUX_LABELS_PATH)

# %%
check_df = pd.read_parquet(paths.OUTPUT_AUX_LABELS_PATH)
check_df.head()
# Out:
#                filename primary_label collection             author  \
# 0  1139490/CSA36385.ogg       1139490        CSA  Fabio A. Sarria-S
# 1  1139490/CSA36389.ogg       1139490        CSA  Fabio A. Sarria-S
# 2  1192948/CSA36358.ogg       1192948        CSA  Fabio A. Sarria-S
# 3  1192948/CSA36366.ogg       1192948        CSA  Fabio A. Sarria-S
# 4  1192948/CSA36373.ogg       1192948        CSA  Fabio A. Sarria-S
#
#              common_name    class secondary_labels    duration
# 0   Ragoniella pulchella  insecta             ['']   98.853375
# 1   Ragoniella pulchella  insecta             ['']   96.537719
# 2  Oxyprora surinamensis  insecta             ['']  116.599812
# 3  Oxyprora surinamensis  insecta             ['']  105.446313
# 4  Oxyprora surinamensis  insecta             ['']  103.631469

# %%
check_df[check_df["duration"].isna()]    # Rows where column is NaN
# Out:
# Empty DataFrame
# Columns: [filename, primary_label, collection, author, common_name, class, secondary_labels, duration]
# Index: []

# %%
primary_list = df['primary_label'].unique()
def filter_list(secondaries, allowed):
    # Convert string representation of list to an actual list
    #actual_list = ast.literal_eval(list_str)
    # Filter the list
    filtered_list = [item for item in secondaries if item in allowed]
    return str(filtered_list)  # Convert back to string if needed

def filter_list(secondaries, allowed):
    if not isinstance(secondaries, (list, str)):
        return secondaries  # Return as is if it's not a list or string
    # Ensure secondaries is a list if it's a string
    if isinstance(secondaries, str):
        secondaries = eval(secondaries)  # Convert string representation of list to actual list
    # Filter the list
    filtered_list = [item for item in secondaries if item in allowed]
    return str(filtered_list)  # Convert back to string if needed

df['secondary_labels'] = df['secondary_labels'].apply(lambda x: filter_list(x, primary_list))

# %%
secondary_labels = df['secondary_labels'].to_list()
seconds_list = [eval(string) for string in secondary_labels]
flattened_seconds = [item for sublist in seconds_list for item in sublist]
item_counts = dict(Counter(flattened_seconds))
total_secondaries = len(flattened_seconds)
total_secondaries
# Out:
# 3941

# %% [markdown]
# It would be good to plot this.

# %%
unique_seconds = set(flattened_seconds)
len(unique_seconds)
# Out:
# 132

# %%
df.head()
# Out:
#   primary_label secondary_labels              filename collection  latitude  \
# 0       1139490               []  1139490/CSA36385.ogg        CSA    7.3206
# 1       1139490               []  1139490/CSA36389.ogg        CSA    7.3206
# 2       1192948               []  1192948/CSA36358.ogg        CSA    7.3791
# 3       1192948               []  1192948/CSA36366.ogg        CSA    7.2800
# 4       1192948               []  1192948/CSA36373.ogg        CSA    7.3791
#
#    longitude        scientific_name            common_name             author  \
# 0   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 1   -73.7128   Ragoniella pulchella   Ragoniella pulchella  Fabio A. Sarria-S
# 2   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 3   -73.8582  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
# 4   -73.7313  Oxyprora surinamensis  Oxyprora surinamensis  Fabio A. Sarria-S
#
#                                             filepath    class    duration
# 0  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta   98.853375
# 1  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta   96.537719
# 2  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  116.599812
# 3  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  105.446313
# 4  /home/olly/Desktop/Kaggle_BC25/Data/Original_D...  insecta  103.631469

# %%
df=df[['filename', 'primary_label', 'secondary_labels', 'collection']]
df.head()
# Out:
#                filename primary_label secondary_labels collection
# 0  1139490/CSA36385.ogg       1139490               []        CSA
# 1  1139490/CSA36389.ogg       1139490               []        CSA
# 2  1192948/CSA36358.ogg       1192948               []        CSA
# 3  1192948/CSA36366.ogg       1192948               []        CSA
# 4  1192948/CSA36373.ogg       1192948               []        CSA

# %%
list(df['secondary_labels'].unique())
# Out:
# ['[]',
#  "['65448', '22976', '476538']",
#  "['compau']",
#  "['65448']",
#  "['65547']",
#  "['22976']",
#  "['soulap1']",
#  "['bubwre1']",
#  "['rinkin1']",
#  "['yectyr1']",
#  "['grekis']",
#  "['trokin']",
#  "['recwoo1', 'trokin', 'rumfly1', 'grekis']",
#  "['rugdov']",
#  "['neocor', 'banana']",
#  "['whtdov']",
#  "['banana']",
#  "['rutjac1', 'paltan1']",
#  "['rutjac1', 'bafibi1', 'banana', 'grekis']",
#  "['bobfly1']",
#  "['socfly1']",
#  "['littin1']",
#  "['sobtyr1']",
#  "['chbant1']",
#  "['yeofly1']",
#  "['greegr']",
#  "['saffin']",
#  "['paltan1']",
#  "['baymac']",
#  "['rtlhum']",
#  "['bobfly1', 'rumfly1', 'cinbec1']",
#  "['plbwoo1']",
#  "['pirfly1']",
#  "['rumfly1']",
#  "['orcpar']",
#  "['trokin', 'grekis']",
#  "['whbant1', 'rebbla1', 'whtdov', 'cinbec1', 'rugdov']",
#  "['pavpig2']",
#  "['whttro1', 'blcjay1', 'trokin']",
#  "['blbwre1', 'crbtan1']",
#  "['yebfly1']",
#  "['yebela1']",
#  "['creoro1', 'cocwoo1']",
#  "['bugtan']",
#  "['orcpar', 'saffin']",
#  "['cotfly1', 'yebela1']",
#  "['cotfly1']",
#  "['bkmtou1']",
#  "['saffin', 'bkcdon']",
#  "['bobfly1', 'whtdov']",
#  "['whtdov', 'whfant1', 'grekis']",
#  "['saffin', 'soulap1', 'grekis']",
#  "['whfant1']",
#  "['rutjac1', 'rugdov']",
#  "['paltan1', 'whtdov']",
#  "['rutjac1']",
#  "['yercac1']",
#  "['stbwoo2', 'rumfly1']",
#  "['smbani']",
#  "['blhpar1', 'cocwoo1']",
#  "['cocwoo1']",
#  "['pirfly1', 'blhpar1', 'cocwoo1']",
#  "['creoro1']",
#  "['gretin1']",
#  "['paltan1', 'saffin']",
#  "['creoro1', 'grekis', 'pavpig2']",
#  "['bkcdon']",
#  "['whtdov', 'soulap1']",
#  "['stbwoo2', 'creoro1', 'cattyr', 'whtdov', 'strfly1', 'grekis', 'pavpig2']",
#  "['greibi1']",
#  "['blbgra1']",
#  "['strcuc1']",
#  "['solsan']",
#  "['yecspi2']",
#  "['purgal2']",
#  "['socfly1', 'grekis']",
#  "['whtdov', 'trokin']",
#  "['ywcpar']",
#  "['blbgra1', 'soulap1']",
#  "['eardov1', 'bafibi1', 'saffin']",
#  "['watjac1', 'trokin', 'grekis']",
#  "['recwoo1']",
#  "['yelori1']",
#  "['whtdov', 'yelori1']",
#  "['cargra1']",
#  "['grasal4', 'brtpar1']",
#  "['sobtyr1', 'stbwoo2', 'rutjac1']",
#  "['greani1', 'grekis']",
#  "['566513']",
#  "['yebela1', 'yecspi2', 'grekis']",
#  "['yebela1', 'socfly1', 'srwswa1']",
#  "['saffin', 'grekis']",
#  "['chfmac1']",
#  "['yecspi2', 'whtdov', 'baymac']",
#  "['yecspi2', 'ruther1', 'baymac']",
#  "['strcuc1', 'watjac1', 'yecspi2', 'whtdov', 'smbani', 'soulap1', 'grekis', 'baymac']",
#  "['strcuc1', 'yecspi2']",
#  "['pirfly1', 'grekis']",
#  "['whtdov', 'grekis', 'pavpig2']",
#  "['laufal1']",
#  "['blbwre1', 'yebfly1']",
#  "['cregua1']",
#  "['cregua1', 'whtdov']",
#  "['srwswa1']",
#  "['smbani', 'grekis', 'bkcdon']",
#  "['smbani', 'soulap1', 'grekis']",
#  "['yebsee1', 'grekis']",
#  "['bubwre1', 'yebela1', 'recwoo1', 'thbeup1']",
#  "['grnkin']",
#  "['yebela1', 'bicwre1', 'trokin']",
#  "['crcwoo1']",
#  "['yebsee1']",
#  "['pirfly1', 'yebela1', 'crcwoo1', 'crbtan1', 'smbani', 'trokin', 'cinbec1', 'rugdov', 'thbeup1']",
#  "['orcpar', 'bugtan', 'trokin', 'rumfly1', 'rugdov']",
#  "['blhpar1']",
#  "['pirfly1', 'linwoo1', 'trokin']",
#  "['bobfly1', 'pirfly1', 'purgal2', 'srwswa1']",
#  "['whbant1', 'recwoo1', 'trokin']",
#  "['whbant1', 'recwoo1', 'crbtan1']",
#  "['crbtan1']",
#  "['orcpar', 'bkmtou1', 'chbant1']",
#  "['rutjac1', 'whtdov', 'rugdov']",
#  "['yercac1', 'chbant1']",
#  "['banana', 'yebfly1']",
#  "['banana', 'pavpig2']",
#  "['blbgra1', 'bugtan', 'yercac1', 'pavpig2']",
#  "['brtpar1']",
#  "['bubwre1', 'cotfly1', 'grekis']",
#  "['ywcpar', 'bubwre1', 'cregua1', 'tropar', 'banana', 'gohman1']",
#  "['stbwoo2']",
#  "['strfly1']",
#  "['greibi1', 'creoro1']",
#  "['amakin1']",
#  "['yebfly1', 'yeofly1']",
#  "['orcpar', 'bicwre1', 'paltan1', 'grasal4', 'grekis']",
#  "['recwoo1', 'orcpar', 'gybmar']",
#  "['crbtan1', 'trokin']",
#  "['yehcar1']",
#  "['whttro1', 'trokin']",
#  "['bubwre1', 'recwoo1', 'rutjac1']",
#  "['ywcpar', 'rtlhum']",
#  "['ragmac1']",
#  "['trokin', 'chfmac1']",
#  "['pirfly1', 'thbeup1']",
#  "['ywcpar', 'linwoo1']",
#  "['cocwoo1', 'baymac']",
#  "['blbwre1']",
#  "['whtdov', 'rugdov']",
#  "['yebela1', 'whtdov']",
#  "['greegr', 'snoegr']",
#  "['pirfly1', 'paltan1', 'socfly1']",
#  "['strher', 'ruther1']",
#  "['rutjac1', 'socfly1', 'yebfly1']",
#  "['tropar']",
#  "['creoro1', 'bugtan', 'grasal4', 'grekis']",
#  "['cinbec1', 'rugdov']",
#  "['blbwre1', 'pirfly1', 'cocwoo1']",
#  "['blbgra1', 'trokin', 'grekis']",
#  "['whtdov', 'grekis']",
#  "['banana', 'trokin', 'grekis']",
#  "['saffin', 'soulap1']",
#  "['yehcar1', 'creoro1', 'cattyr', 'whtdov', 'pavpig2']",
#  "['yebela1', 'grekis']",
#  "['fotfly', 'trokin', 'grekis']",
#  "['strher', 'rinkin1', 'rumfly1', 'grekis']",
#  "['blbgra1', 'saffin']",
#  "['orcpar', 'grekis']",
#  "['bugtan', 'soulap1']",
#  "['yehcar1', 'creoro1', 'spepar1', 'yercac1']",
#  "['bicwre1', 'yelori1']",
#  "['blcjay1']",
#  "['orcpar', 'bicwre1']",
#  "['orcpar', 'bicwre1', 'rutpuf1']",
#  "['socfly1', 'whtdov', 'thbeup1']",
#  "['ywcpar', 'banana', 'saffin', 'rumfly1']",
#  "['rufmot1']",
#  "['rugdov', 'pavpig2']",
#  "['yercac1', 'pavpig2']",
#  "['blcant4', 'grekis', 'pavpig2']",
#  "['greani1', 'blcant4']",
#  "['crebob1']",
#  "['greani1']",
#  "['sobtyr1', 'grekis']",
#  "['bucmot3', 'trokin']",
#  "['rumfly1', 'rugdov']",
#  "['sobtyr1', 'orcpar', 'socfly1', 'trokin']",
#  "['banana', 'gretin1', 'yectyr1']",
#  "['orcpar', 'rumfly1', 'rugdov']",
#  "['bobfly1', 'grekis']",
#  "['yebela1', 'gybmar', 'bucmot3']",
#  "['cotfly1', 'grekis']",
#  "['blbgra1', 'grekis', 'laufal1']",
#  "['bobfly1', 'blbgra1']",
#  "['whtdov', 'pavpig2']",
#  "['watjac1']",
#  "['colcha1']",
#  "['whtdov', 'cocwoo1']",
#  "['crbtan1', 'trokin', 'wbwwre1']",
#  "['olipic1']",
#  "['thbeup1']",
#  "['pirfly1', 'rumfly1']",
#  "['recwoo1', 'orcpar']",
#  "['cocwoo1', 'rufmot1']",
#  "['ywcpar', 'whtdov']",
#  "['whttro1']",
#  "['roahaw']",
#  "['pirfly1', 'socfly1', 'whfant1']",
#  "['littin1', 'roahaw']",
#  "['yercac1', 'rumfly1']",
#  "['whtdov', 'banana']",
#  "['orcpar', 'crbtan1', 'socfly1', 'thbeup1']",
#  "['rtlhum', 'crbtan1', 'socfly1', 'thbeup1']",
#  "['crbtan1', 'banana']",
#  "['rtlhum', 'cotfly1', 'yebela1', 'crbtan1', 'whtdov']",
#  "['rutjac1', 'whtdov']",
#  "['blbgra1', 'bugtan', 'trokin']",
#  "['gycwor1']",
#  "['speowl1']",
#  "['whbman1']",
#  "['rtlhum', 'banana']",
#  "['cotfly1', 'linwoo1', 'whtdov', 'saffin', 'rugdov']",
#  "['cotfly1', 'saffin']",
#  "['strcuc1', 'grekis']",
#  "['pirfly1', 'yercac1', 'grekis']",
#  "['paltan1', 'socfly1', 'grekis']",
#  "['trsowl', 'whtdov', 'grekis', 'gycwor1']",
#  "['strcuc1', 'grekis', 'gycwor1']",
#  "['sobtyr1', 'whtdov']",
#  "['strcuc1', 'grekis', 'baymac']",
#  "['bobfly1', 'creoro1', 'whtdov', 'yercac1', 'pavpig2', 'baymac']",
#  "['eardov1', 'grekis']",
#  "['cocher1']",
#  "['eardov1', 'soulap1', 'grekis']",
#  "['pirfly1', 'yectyr1']",
#  "['gretin1', 'cocwoo1']",
#  "['greani1', 'yebela1', 'crcwoo1', 'crbtan1', 'smbani', 'cocwoo1', 'cinbec1', 'thbeup1']",
#  "['cotfly1', 'tropar', 'grekis']",
#  "['sobtyr1', 'recwoo1', 'rugdov']",
#  "['greibi1', 'whtdov']",
#  "['greani1', 'creoro1']",
#  "['creoro1', 'whtdov']",
#  "['spepar1', 'cotfly1', 'blhpar1', 'grekis']",
#  "['bicwre1']",
#  "['bugtan', 'rumfly1']",
#  "['blkvul']",
#  "['greegr', 'bbwduc']",
#  "['bkmtou1', 'chbant1']",
#  "['blhpar1', 'banana']",
#  "['stbwoo2', 'yebfly1', 'yeofly1']",
#  "['crbtan1', 'strfly1']",
#  "['whttro1', 'gretin1']",
#  "['blhpar1', 'gretin1']",
#  "['whbant1']",
#  "['pirfly1', 'orcpar']",
#  "['blbwre1', 'plbwoo1']",
#  "['littin1', 'yebela1']",
#  "['cregua1', 'whtdov', 'bkmtou1']",
#  "['crbtan1', 'cocwoo1']",
#  "['paltan1', 'thbeup1']",
#  "['strcuc1', 'bugtan']",
#  "['compot1']",
#  "['grekis', 'baymac']",
#  "['bugtan', 'soulap1', 'trokin']",
#  "['strowl1']",
#  "['bobher1']",
#  "['trsowl']",
#  "['grepot1']",
#  "['plbwoo1', 'compau']",
#  "['yebela1', 'bugtan']",
#  "['rutjac1', 'banana']",
#  "['bugtan', 'grekis']",
#  "['strfly1', 'grekis']",
#  "['cinbec1']",
#  "['ywcpar', 'neocor']",
#  "['neocor', 'recwoo1']",
#  "['bugtan', 'trokin', 'yectyr1']",
#  "['grekis', 'rugdov']",
#  "['whtdov', 'grekis', 'rugdov']",
#  "['pirfly1', 'cocwoo1']",
#  "['cregua1', 'rumfly1', 'cocwoo1']",
#  "['rtlhum', 'thbeup1']",
#  "['pirfly1', 'whbman1', 'chfmac1']",
#  "['greani1', 'pirfly1', 'bugtan', 'banana', 'cinbec1']",
#  "['cotfly1', 'pirfly1', 'srwswa1', 'trokin', 'rugdov', 'laufal1']",
#  "['sobtyr1', 'whtdov', 'grekis']",
#  "['yebela1', 'crbtan1', 'grekis']",
#  "['whtdov', 'bkmtou1']",
#  "['grasal4', 'grekis']",
#  "['mastit1']",
#  "['blhpar1', 'bkmtou1']",
#  "['yercac1', 'grekis']",
#  "['paltan1', 'yercac1', 'trokin']",
#  "['paltan1', 'yercac1']",
#  "['yectyr1', 'pavpig2']",
#  "['strcuc1', 'yercac1', 'grekis']",
#  "['greani1', 'stbwoo2', 'rumfly1']",
#  "['greani1', 'stbwoo2']",
#  "['pirfly1', 'labter1']",
#  "['pirfly1', 'rugdov']",
#  "['banana', 'soulap1']",
#  "['pirfly1', 'littin1', 'blhpar1', 'recwoo1', 'bugtan']",
#  "['blbgra1', 'trokin']",
#  "['yebela1', 'trokin', 'laufal1']",
#  "['cregua1', 'whbman1', 'chfmac1', 'thbeup1']",
#  "['blcant4']",
#  "['recwoo1', 'grekis']",
#  "['rutpuf1']",
#  "['recwoo1', 'grekis', 'brtpar1']",
#  "['orcpar', 'brtpar1']",
#  "['recwoo1', 'rutpuf1']",
#  "['bicwre1', 'grekis']",
#  "['recwoo1', 'thbeup1']",
#  "['whtdov', 'strfly1']",
#  "['grekis', 'bkcdon']",
#  "['bobfly1', 'pirfly1', 'orcpar', 'piepuf1', 'gretin1', 'trokin', 'rumfly1']",
#  "['cotfly1', 'pirfly1']",
#  "['pirfly1', 'recwoo1', 'yercac1', 'cocwoo1', 'cinbec1', 'thbeup1']",
#  "['cotfly1', 'yehbla2']",
#  "['rebbla1']",
#  "['bubwre1', 'whtdov']",
#  "['labter1', 'pavpig2']",
#  "['snoegr']",
#  "['rosspo1']",
#  "['woosto']",
#  "['rosspo1', 'woosto']",
#  "['anhing']",
#  "['tropar', 'soulap1']",
#  "['spbwoo1']",
#  "['cotfly1', 'banana']",
#  "['whtdov', 'rinkin1']",
#  "['strfly1', 'ruther1']",
#  "['whtdov', 'grekis', 'baymac']",
#  "['yercac1', 'baymac']",
#  "['stbwoo2', 'rugdov']",
#  "['stbwoo2', 'pirfly1']",
#  "['littin1', 'whtdov']",
#  "['yebela1', 'banana', 'rugdov']",
#  "['bicwre1', 'crebob1', 'whtdov', 'grasal4', 'trokin']",
#  "['neocor']",
#  "['saffin', 'trokin']",
#  "['socfly1', 'trokin']",
#  "['yebela1', 'paltan1']",
#  "['cargra1', 'trokin']",
#  "['cotfly1', 'yeofly1', 'yectyr1']",
#  "['orcpar', 'rumfly1']",
#  "['trokin', 'rumfly1']",
#  "['strcuc1', 'creoro1', 'pavpig2']",
#  "['bugtan', 'trokin']",
#  "['tropar', 'rugdov']",
#  "['whtdov', 'compau']",
#  "['yebfly1', 'trokin']",
#  "['rinkin1', 'grekis']",
#  "['whtdov', 'saffin']",
#  "['trsowl', 'yeofly1', 'laufal1']",
#  "['rtlhum', 'bugtan']",
#  "['watjac1', 'smbani', 'grekis']",
#  "['grekis', 'gycwor1']",
#  "['tropar', 'grekis']",
#  "['linwoo1']",
#  "['orcpar', 'trokin']",
#  "['rtlhum', 'pirfly1', 'yebela1', 'socfly1']",
#  "['yebsee1', 'blbgra1']",
#  "['blbgra1', 'saffin', 'grekis']",
#  "['bbwduc']",
#  "['bobfly1', 'rumfly1']",
#  "['amakin1', 'srwswa1']",
#  "['cattyr']",
#  "['pirfly1', 'yeofly1']",
#  "['bicwre1', 'compau']",
#  "['cotfly1', 'bugtan']",
#  "['blbgra1', 'grekis']",
#  "['bubwre1', 'blbgra1', 'grekis', 'rugdov']",
#  "['banana', 'grekis']",
#  "['gybmar']",
#  "['whwswa1']",
#  "['cargra1', 'bbwduc']",
#  "['blbgra1', 'banana', 'grekis']",
#  "['yebsee1', 'smbani']",
#  "['rutjac1', 'blbgra1', 'whtdov', 'rinkin1', 'rugdov']",
#  "['blbgra1', 'smbani', 'rugdov']",
#  "['rutjac1', 'smbani']",
#  "['stbwoo2', 'grekis']",
#  "['bobfly1', 'socfly1']",
#  "['bobfly1', 'paltan1']",
#  "['cotfly1', 'colcha1']",
#  "['paltan1', 'colcha1']",
#  "['yebela1', 'recwoo1', 'orcpar', 'whtdov', 'thbeup1']",
#  "['yebela1', 'recwoo1', 'orcpar', 'whtdov', 'bugtan', 'smbani', 'piepuf1', 'trokin', 'cocwoo1', 'yectyr1', 'rugdov']",
#  "['whtdov', 'smbani', 'strfly1']",
#  "['whtdov', 'mastit1', 'grekis']",
#  "['blbgra1', 'saffin', 'yeofly1']",
#  "['bkmtou1', 'mastit1']",
#  "['cotfly1', 'yectyr1', 'thbeup1']",
#  "['yehcar1', 'rugdov']",
#  "['banana', 'chbant1']",
#  "['yebela1', 'paltan1', 'grekis']",
#  "['yebela1', 'paltan1', 'trokin', 'grekis']",
#  "['recwoo1', 'orcpar', 'paltan1', 'crbtan1', 'trokin']",
#  "['watjac1', 'grekis']",
#  "['soulap1', 'snoegr']",
#  "['socfly1', 'soulap1']",
#  "['yecspi2', 'yehbla2']",
#  "['ywcpar', 'whbant1', 'rutjac1', 'blcjay1', 'saffin']",
#  "['whtdov', 'grasal4']",
#  "['recwoo1', 'bicwre1']",
#  "['cotfly1', 'recwoo1']",
#  "['recwoo1', 'whtdov', 'thbeup1']",
#  "['yebela1', 'gybmar', 'bugtan']",
#  "['yebela1', 'brtpar1']",
#  "['spepar1']",
#  "['crcwoo1', 'grekis']",
#  "['cotfly1', 'yecspi2', 'y00678']",
#  "['bubwre1', 'rutjac1', 'pavpig2']",
#  "['blcant4', 'brtpar1', 'whbman1']",
#  "['creoro1', 'orcpar', 'bicwre1', 'crebob1', 'grasal4', 'grekis', 'brtpar1']",
#  "['piwtyr1', 'recwoo1', 'rubsee1', 'soulap1', 'rugdov']",
#  "['creoro1', 'yercac1']",
#  "['creoro1', 'grekis']",
#  "['cocwoo1', 'thbeup1']",
#  "['rinkin1', 'strfly1', 'trokin']",
#  "['creoro1', 'yercac1', 'baymac']",
#  "['creoro1', 'grekis', 'baymac']",
#  "['cattyr', 'whtdov', 'soulap1', 'yercac1', 'baymac']",
#  "['socfly1', 'yeofly1']",
#  "['rinkin1', 'bkcdon']",
#  "['paltan1', 'grekis', 'baymac']",
#  "['yebela1', 'socfly1', 'grekis']",
#  "['strher', 'whtdov', 'yercac1']",
#  "['grekis', 'secfly1']",
#  "['watjac1', 'pirfly1', 'rumfly1', 'cocwoo1']",
#  "['sobtyr1', 'bugtan', 'rumfly1']",
#  "['bubwre1', 'pirfly1', 'whtdov', 'smbani', 'grekis', 'bkcdon']",
#  "['banana', 'saffin']",
#  "['whbman1', 'chfmac1']",
#  "['cotfly1', 'cinbec1']",
#  "['littin1', 'banana']",
#  "['bobfly1', 'grekis', 'gycwor1']",
#  "['socfly1', 'whtdov', 'yeofly1']",
#  "['strcuc1', 'socfly1', 'whtdov', 'yeofly1']",
#  "['blhpar1', 'yercac1']",
#  "['orcpar', 'yercac1', 'trokin']",
#  "['yebela1', 'recwoo1', 'yectyr1']",
#  "['socfly1', 'banana', 'trokin', 'rumfly1', 'grekis']",
#  "['blbwre1', 'bobfly1', 'cocwoo1', 'whbman1', 'thbeup1']",
#  "['greani1', 'greibi1', 'stbwoo2']",
#  "['blhpar1', 'bugtan']",
#  "['stbwoo2', 'paltan1']",
#  "['wbwwre1']",
#  "['rtlhum', 'orcpar', 'cocwoo1']",
#  "['bucmot3']",
#  "['recwoo1', 'bugtan', 'trokin']",
#  "['secfly1']",
#  "['anhing', 'bbwduc']",
#  "['greani1', 'blbwre1', 'blbgra1', 'whtdov', 'cinbec1', 'thbeup1']",
#  "['yecspi2', 'soulap1', 'grekis']",
#  "['yecspi2', 'grekis']",
#  "['cotfly1', 'yebela1', 'socfly1', 'trokin', 'grekis']",
#  "['neocor', 'snoegr']",
#  "['watjac1', 'yecspi2']",
#  "['creoro1', 'blhpar1', 'chfmac1']",
#  "['strcuc1', 'smbani']",
#  "['crbtan1', 'whtdov']",
#  "['blbgra1', 'smbani']",
#  "['blbgra1', 'socfly1', 'rugdov']",
#  "['yelori1', 'brtpar1']",
#  "['strcuc1', 'pirfly1']",
#  "['neocor', 'leagre', 'trokin']",
#  "['whtdov', 'bucmot3']",
#  "['grekis', 'grnkin']",
#  "['rebbla1', 'gybmar']",
#  "['cotfly1', 'strfly1']",
#  "['pirfly1', 'yebela1', 'banana', 'trokin']",
#  "['pirfly1', 'blbgra1', 'bugtan', 'trokin']",
#  "['paltan1', 'srwswa1']",
#  "['grekis', 'pavpig2']",
#  "['paltan1', 'trokin']",
#  "['cotfly1', 'grekis', 'rugdov']",
#  "['trokin', 'laufal1']",
#  "['littin1', 'rutjac1', 'chbant1']",
#  "['tropar', 'yebfly1']",
#  "['orcpar', 'yebfly1', 'bucmot3']",
#  "['butsal1', 'yebsee1', 'crbtan1', 'trokin', 'rugdov', 'thbeup1']",
#  "['blbwre1', 'whbant1']",
#  "['yebfly1', 'cinbec1']",
#  "['sobtyr1', 'bubwre1', 'whbant1', 'littin1', 'yebela1', 'recwoo1', 'strfly1', 'trokin']",
#  "['linwoo1', 'socfly1']",
#  "['whtdov', 'yebfly1']",
#  "['butsal1']",
#  "['eardov1']",
#  "['leagre', 'blbgra1', 'smbani']",
#  "['creoro1', 'pirfly1']",
#  "['yebela1', 'blbgra1', 'saffin']",
#  "['stbwoo2', 'yebela1', 'banana']",
#  "['whtdov', 'tropar']",
#  "['saffin', 'rugdov']",
#  "['palhor2']",
#  "['littin1', 'gycwor1']",
#  "['pirfly1', 'plctan1', 'bkmtou1']",
#  "['watjac1', 'piwtyr1', 'recwoo1', 'blbgra1', 'socfly1', 'rebbla1', 'trokin', 'yectyr1', 'rugdov', 'thbeup1']",
#  "['yebela1', 'gybmar', 'cocwoo1']",
#  "['yebela1', 'whbman1']",
#  "['bobfly1', 'blbgra1', 'smbani']",
#  "['ragmac1', 'chfmac1']",
#  "['crbtan1', 'blcjay1']",
#  "['soulap1', 'grekis']",
#  "['eardov1', 'srwswa1']",
#  "['paltan1', 'bbwduc']",
#  "['banana', 'trokin']",
#  "['bobfly1', 'pirfly1', 'bugtan', 'saffin', 'grekis']",
#  "['creoro1', 'baymac']",
#  "['bubwre1', 'laufal1']",
#  "['soulap1', 'baymac']",
#  "['bkcdon', 'baymac']",
#  "['greibi1', 'creoro1', 'trsowl', 'gycwor1']",
#  "['bobfly1', 'paltan1', 'whtdov', 'grekis', 'pavpig2']",
#  "['yebela1', 'paltan1', 'banana']",
#  "['colara1']",
#  "['pirfly1', 'trokin', 'grekis']",
#  "['pirfly1', 'trokin']",
#  "['littin1', 'orcpar']",
#  "['creoro1', 'yeofly1']",
#  "['laufal1', 'chbant1']",
#  "['yebela1', 'grasal4', 'trokin', 'grekis']",
#  "['yebela1', 'socfly1']",
#  "['trokin', 'rugdov']",
#  "['socfly1', 'grekis', 'rugdov']",
#  "['stbwoo2', 'trokin', 'grekis']",
#  "['yecspi2', 'bafibi1']",
#  "['cotfly1', 'smbani']",
#  "['smbani', 'bbwduc']",
#  "['trokin', 'bbwduc']",
#  "['rutjac1', 'grekis']",
#  "['greani1', 'yecspi2', 'whtdov', 'grekis', 'whbman1']",
#  "['blbwre1', 'colcha1']",
#  "['strcuc1', 'bugtan', 'grekis']",
#  "['whbant1', 'littin1']",
#  "['blbgra1', 'whtdov', 'banana', 'brtpar1']",
#  "['littin1', 'chbant1']",
#  "['yecspi2', 'soulap1']",
#  "['pirfly1', 'piepuf1', 'trokin']",
#  "['linwoo1', 'blbgra1', 'piepuf1']",
#  "['bugtan', 'rugdov']",
#  "['leagre']",
#  "['blhpar1', 'yebsee1', 'thbeup1']",
#  "['amakin1', 'pavpig2']",
#  "['cotfly1', 'rumfly1']",
#  "['grekis', 'colcha1']",
#  "['tropar', 'laufal1']",
#  "['bugtan', 'saffin']",
#  "['yebela1', 'soulap1', 'grekis']",
#  "['strcuc1', 'compau']",
#  "['greani1', 'yebela1']",
#  "['crebob1', 'soulap1']",
#  "['palhor2', 'grekis']",
#  "['whtdov', 'trokin', 'grekis']",
#  "['grekis', 'yectyr1']",
#  "['bobfly1', 'yercac1']",
#  "['whtdov', 'mastit1']",
#  "['bobfly1', 'tropar']",
#  "['recwoo1', 'trokin']",
#  "['yercac1', 'gycwor1']",
#  "['bobfly1', 'yeofly1']",
#  "['strcuc1', 'blbgra1', 'trokin']",
#  "['eardov1', 'rugdov']",
#  "['greibi1', 'cotfly1', 'grekis', 'gycwor1']",
#  "['rebbla1', 'trokin']",
#  "['watjac1', 'paltan1']",
#  "['blbgra1', 'bbwduc']",
#  "['trsowl', 'laufal1']",
#  "['grasal4']",
#  "['crebob1', 'bugtan', 'grekis']",
#  "['blcjay1', 'yeofly1', 'grekis']",
#  "['spbwoo1', 'bugtan', 'rugdov']",
#  "['saffin', 'rumfly1']",
#  "['rumfly1', 'grekis']",
#  "['yercac1', 'rumfly1', 'yectyr1']",
#  "['whtdov', 'colcha1']",
#  "['whtdov', 'yeofly1', 'colcha1']",
#  "['strfly1', 'thbeup1']",
#  "['cotfly1', 'neocor', 'recwoo1', 'socfly1', 'soulap1']",
#  "['pirfly1', 'soulap1', 'grekis']",
#  "['greibi1', 'creoro1', 'grekis']",
#  "['greibi1', 'creoro1', 'whtdov', 'strfly1', 'grekis', 'ruther1', 'baymac']",
#  "['whtdov', 'whfant1']",
#  "['blbgra1', 'whtdov']",
#  "['smbani', 'grekis']",
#  "['pirfly1', 'banana']",
#  "['yecspi2', 'whtdov']",
#  "['pirfly1', 'whtdov']",
#  "['yehbla2']",
#  "['orcpar', 'bugtan']",
#  "['sobtyr1', 'whbant1', 'rebbla1', 'bugtan', 'thbeup1']",
#  "['yebela1', 'whtdov', 'trokin', 'rugdov']",
#  "['yeofly1', 'grekis']",
#  "['whbant1', 'bugtan', 'grekis']",
#  "['yercac1', 'grekis', 'pavpig2']",
#  "['smbani', 'soulap1', 'grekis', 'pavpig2']",
#  "['fotfly', 'grekis']",
#  "['soulap1', 'trokin', 'grekis']",
#  "['blbwre1', 'recwoo1']",
#  "['stbwoo2', 'whtdov']",
#  "['stbwoo2', 'whtdov', 'grekis']",
#  "['rinkin1', 'trokin']",
#  "['orcpar', 'crbtan1']",
#  "['creoro1', 'paltan1', 'banana', 'cocwoo1']",
#  "['blhpar1', 'saffin', 'grekis']",
#  "['stbwoo2', 'creoro1', 'whtdov', 'baymac']",
#  "['yehcar1', 'whtdov']",
#  "['bobfly1', 'rugdov', 'laufal1']",
#  "['yebela1', 'yecspi2', 'grekis', 'rugdov']",
#  "['blbgra1', 'grekis', 'rugdov']",
#  "['whmtyr1']",
#  "['blbwre1', 'blbgra1', 'crbtan1', 'rumfly1', 'rugdov']",
#  "['yebela1', 'whtdov', 'cinbec1', 'rugdov']",
#  "['blhpar1', 'socfly1']",
#  "['sobtyr1', 'bugtan']",
#  "['creoro1', 'pirfly1', 'paltan1', 'brtpar1']",
#  "['yebela1', 'recwoo1', 'saffin', 'yeofly1']",
#  "['blbwre1', 'whbman1']",
#  "['greani1', 'yebela1', 'grekis', 'bkcdon']",
#  "['strher', 'yebela1', 'ruther1']",
#  "['neocor', 'yebela1', 'yecspi2', 'compau']",
#  "['strcuc1', 'pirfly1', 'bugtan']",
#  "['yebela1', 'compau']",
#  "['orcpar', 'bicwre1', 'bugtan']",
#  "['tropar', 'cinbec1']",
#  "['whbant1', 'crbtan1']",
#  "['sobtyr1', 'bubwre1', 'pavpig2']",
#  "['whtdov', 'pavpig2', 'bbwduc']",
#  "['whtdov', 'grnkin']",
#  "['socfly1', 'whtdov', 'bbwduc']",
#  "['watjac1', 'yercac1']",
#  "['greibi1', 'pavpig2']",
#  "['soulap1', 'gycwor1']",
#  "['labter1']",
#  "['cotfly1', 'blcjay1']",
#  "['soulap1', 'trokin']",
#  "['soulap1', 'compau']",
#  "['compot1', 'gycwor1']",
#  "['grepot1', 'compot1', 'compau']",
#  "['bobfly1', 'whtdov', 'srwswa1', 'rumfly1', 'grekis']",
#  "['yehbla2', 'bbwduc']",
#  "['soulap1', 'rugdov']",
#  "['cotfly1', 'yebela1', 'orcpar', 'yectyr1', 'colcha1']",
#  "['sobtyr1', 'orcpar', 'yebfly1']",
#  "['littin1', 'cocwoo1']",
#  "['bubwre1', 'pirfly1']",
#  "['littin1', 'orcpar', 'crbtan1']",
#  "['whtdov', 'banana', 'grekis']",
#  "['socfly1', 'whtdov']",
#  "['yehcar1', 'grekis']",
#  "['yebela1', 'yecspi2', 'smbani', 'grekis', 'rugdov']",
#  "['rutjac1', 'chbant1']",
#  "['yebfly1', 'yectyr1']",
#  "['yebela1', 'yebfly1']",
#  "['yecspi2', 'bbwduc']",
#  "['smbani', 'soulap1']",
#  "['strher', 'yebela1', 'grekis']",
#  "['cotfly1', 'yebela1', 'socfly1']",
#  "['pirfly1', 'orcpar', 'trokin', 'cinbec1']",
#  "['yebfly1', 'trokin', 'cinbec1']",
#  "['blbwre1', 'cocwoo1']",
#  "['bobfly1', 'creoro1', 'grekis']",
#  "['yebela1', 'recwoo1', 'trokin']",
#  "['paltan1', 'grekis']",
#  "['creoro1', 'grekis', 'pavpig2', 'baymac']",
#  "['strcuc1', 'yehcar1', 'bobfly1', 'creoro1', 'cattyr', 'yercac1', 'grekis', 'pavpig2', 'baymac']",
#  "['eardov1', 'rinkin1', 'soulap1']",
#  "['rutjac1', 'pavpig2']",
#  "['greani1', 'bubwre1', 'pirfly1', 'grekis']",
#  "['gybmar', 'soulap1']",
#  "['stbwoo2', 'soulap1', 'grekis', 'compau']",
#  "['socfly1', 'bugtan', 'saffin', 'trokin']",
#  "['orcpar', 'socfly1', 'trokin', 'grekis']",
#  "['whtdov', 'rumfly1']",
#  "['yecspi2', 'whtdov', 'yebfly1', 'grekis']",
#  "['strcuc1', 'soulap1', 'grekis']",
#  "['eardov1', 'smbani']",
#  "['whtdov', 'trokin', 'grekis', 'gycwor1']",
#  "['socfly1', 'soulap1', 'trokin']",
#  "['blhpar1', 'crbtan1', 'whtdov', 'banana', 'trokin', 'rumfly1']",
#  "['blbwre1', 'creoro1', 'cotfly1', 'bkmtou1', 'chbant1']",
#  "['fotfly']",
#  "['eardov1', 'trokin', 'grekis']",
#  "['cotfly1', 'whtdov', 'rumfly1', 'rugdov']",
#  "['sobtyr1', 'bubwre1', 'rutjac1']",
#  "['ywcpar', 'recwoo1', 'chfmac1']",
#  "['banana', 'rugdov']",
#  "['yebela1', 'banana']",
#  "['whtdov', 'bugtan', 'grekis']",
#  "['orcpar', 'paltan1', 'whtdov', 'yectyr1']",
#  "['yebela1', 'crbtan1', 'soulap1', 'trokin', 'thbeup1']",
#  "['bubwre1', 'blbgra1']",
#  "['bubwre1', 'yebela1', 'blbgra1']",
#  "['linwoo1', 'blbgra1']",
#  "['rutjac1', 'srwswa1']",
#  "['bubwre1', 'smbani']",
#  "['yebela1', 'saffin', 'srwswa1']",
#  "['yebela1', 'bkcdon', 'rugdov']",
#  "['greibi1', 'crcwoo1']",
#  "['greani1', 'trokin', 'grekis']",
#  "['watjac1', 'whtdov']",
#  "['creoro1', 'soulap1']",
#  "['cotfly1', 'banana', 'thbeup1']",
#  "['bubwre1', 'yectyr1']",
#  "['bubwre1', 'grekis']",
#  "['neocor', 'y00678', 'soulap1']",
#  "['bobfly1', 'grekis', 'baymac']",
#  "['strcuc1', 'bobfly1', 'cattyr', 'whtdov', 'yercac1', 'pavpig2', 'baymac']",
#  "['orcpar', 'bicwre1', 'whtdov']",
#  "['cotfly1', 'yebela1', 'grekis', 'rugdov']",
#  "['sobtyr1', 'secfly1']",
#  "['pirfly1', 'socfly1', 'whtdov']",
#  "['cotfly1', 'mastit1']",
#  "['whtdov', 'palhor2', 'rumfly1', 'rugdov']",
#  "['yebela1', 'whfant1']",
#  "['whtdov', 'soulap1', 'grekis']",
#  "['cotfly1', 'crbtan1']",
#  "['bobfly1', 'trokin']",
#  "['stbwoo2', 'crcwoo1', 'grekis']",
#  "['rutjac1', 'saffin']",
#  "['whtdov', 'yercac1']",
#  "['bobfly1', 'soulap1', 'rugdov']",
#  "['whtdov', 'saffin', 'soulap1', 'grekis']",
#  "['pirfly1', 'cargra1']",
#  "['pirfly1', 'cargra1', 'paltan1']",
#  "['cargra1', 'grasal4']",
#  "['cotfly1', 'pirfly1', 'yebela1', 'cargra1', 'grasal4', 'trokin', 'grekis']",
#  "['pirfly1', 'yebela1', 'cargra1', 'paltan1', 'grasal4', 'brtpar1']",
#  "['whttro1', 'chbant1']",
#  "['littin1', 'blbgra1', 'rebbla1', 'whtdov', 'smbani', 'trokin', 'yectyr1']",
#  "['plbwoo1', 'cocwoo1']",
#  "['yebela1', 'whtdov', 'bugtan', 'rumfly1']",
#  "['cotfly1', 'whtdov']",
#  "['bobfly1', 'whtdov', 'pavpig2']",
#  "['greibi1', 'whtdov', 'baymac']",
#  "['bugtan', 'trokin', 'grekis']",
#  "['cotfly1', 'pirfly1', 'grekis']",
#  "['yebela1', 'smbani']",
#  "['recwoo1', 'soulap1']",
#  "['chfmac1', 'baymac']",
#  "['blbwre1', 'cotfly1', 'rugdov', 'thbeup1']",
#  "['yehcar1', 'orcpar', 'trokin']",
#  "['neocor', 'trokin']"]

# %%
len(list(df['secondary_labels'].unique()))
# Out:
# 744

# %% [markdown]
# ## Varify the audiofiles
#
# I would like to be sure that the audio files can be opend OK

# %%
def crop_or_pad(y, length,  train='train', background_paths=None):
    initial_length = len(y)
    if 3 * initial_length < length:
        y = np.concatenate([y,np.zeros(initial_length),y])
    elif 2 * initial_length < length:
        y = np.concatenate([y,np.zeros(initial_length//2),y])
    if len(y) < length:
        y = np.concatenate([y, y]) 
    
    def Normalize(array):
        max_vol = np.abs(array).max()
        return array * 1 / max_vol

    if len(y) < length:
        difference = length - len(y)
        fill=np.zeros(difference)
        y = np.concatenate([y, fill])
    else:
        if train != 'train':
            start = 0
        else:
            start = 0
            start = np.random.randint(len(y) - length)
        y = y[start: start + length]
    y = Normalize(y)
    return y

def open_audio_clip(path, starts=None):    
    try:  
        y, _ = torchaudio.load(path)
        if y.ndim == 2 and y.shape[0] == 2:
            print(f'converting {path} to mono')
            y = torch.mean(y, dim=0).unsqueeze(0)  # from stereo to mono
        y = y.squeeze().numpy() 
    except Exception as e:
        y = np.random.randn(5*320000) 
        print(f'could not open {path}')
        print(e)
    
    if not np.isfinite(y).all():
        y[np.isnan(y)] = np.mean(y)
        y[np.isinf(y)] = np.mean(y)

    y = crop_or_pad(y, 10)  # background_paths=self.back_pths
    return y

# %%
tier1_files = [str(paths.DATA_FOLDER / fn) for fn in df['filename'].to_list()]

tier1_files[:5]
# Out:
# ['/home/olly/Desktop/Kaggle_BC25/Data/1139490/CSA36385.ogg',
#  '/home/olly/Desktop/Kaggle_BC25/Data/1139490/CSA36389.ogg',
#  '/home/olly/Desktop/Kaggle_BC25/Data/1192948/CSA36358.ogg',
#  '/home/olly/Desktop/Kaggle_BC25/Data/1192948/CSA36366.ogg',
#  '/home/olly/Desktop/Kaggle_BC25/Data/1192948/CSA36373.ogg']

# %%
def play_audio(file_path):
    audio_abe, sr_abe = torchaudio.load(file_path)
    print(sr_abe)
    print(audio_abe.shape)
    return Audio(data=audio_abe.numpy(), rate=sr_abe)

play_audio(tier1_files[0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[44], line 7
#       4     print(audio_abe.shape)
#       5     return Audio(data=audio_abe.numpy(), rate=sr_abe)
# ----> 7 play_audio(tier1_files[0])
#
# Cell In[44], line 2, in play_audio(file_path)
#       1 def play_audio(file_path):
# ----> 2     audio_abe, sr_abe = torchaudio.load(file_path)
#       3     print(sr_abe)
#       4     print(audio_abe.shape)
#
# File ~/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torchaudio/_backend/utils.py:205, in get_load_func.<locals>.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     128 """Load audio data from source.
#     129
#     130 By default (``normalize=True``, ``channels_first=True``), this function returns Tensor with
#    (...)
#     202         `[channel, time]` else `[time, channel]`.
#     203 """
#     204 backend = dispatcher(uri, format, backend)
# --> 205 return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#
# File ~/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torchaudio/_backend/ffmpeg.py:297, in FFmpegBackend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#     287 @staticmethod
#     288 def load(
#     289     uri: InputType,
#    (...)
#     295     buffer_size: int = 4096,
#     296 ) -> Tuple[torch.Tensor, int]:
# --> 297     return load_audio(uri, frame_offset, num_frames, normalize, channels_first, format)
#
# File ~/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torchaudio/_backend/ffmpeg.py:88, in load_audio(src, frame_offset, num_frames, convert, channels_first, format, buffer_size)
#      86 if hasattr(src, "read") and format == "vorbis":
#      87     format = "ogg"
# ---> 88 s = torchaudio.io.StreamReader(src, format, None, buffer_size)
#      89 sample_rate = int(s.get_src_stream_info(s.default_audio_stream).sample_rate)
#      90 filter = _get_load_filter(frame_offset, num_frames, convert)
#
# File ~/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torio/io/_streaming_media_decoder.py:526, in StreamingMediaDecoder.__init__(self, src, format, option, buffer_size)
#     524     self._be = ffmpeg_ext.StreamingMediaDecoderFileObj(src, format, option, buffer_size)
#     525 else:
# --> 526     self._be = ffmpeg_ext.StreamingMediaDecoder(os.path.normpath(src), format, option)
#     528 i = self._be.find_best_audio_stream()
#     529 self._default_audio_stream = None if i < 0 else i
#
# RuntimeError: Failed to open the input "/home/olly/Desktop/Kaggle_BC25/Data/1139490/CSA36385.ogg" (No such file or directory).
# Exception raised from get_input_format_context at /__w/_temp/conda_environment_8430229400/conda-bld/torchaudio_1711422726100/work/src/libtorio/ffmpeg/stream_reader/stream_reader.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x772e09b7dd87 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x772e09b2e75f in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torch/lib/libc10.so)
# frame #2: <unknown function> + 0x42904 (0x772db8dbf904 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torio/lib/libtorio_ffmpeg6.so)
# frame #3: torio::io::StreamingMediaDecoder::StreamingMediaDecoder(std::string const&, std::optional<std::string> const&, std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x14 (0x772db8dc2304 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torio/lib/libtorio_ffmpeg6.so)
# frame #4: <unknown function> + 0x3ab5e (0x772d67589b5e in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torio/lib/_torio_ffmpeg6.so)
# frame #5: <unknown function> + 0x32737 (0x772d67581737 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torio/lib/_torio_ffmpeg6.so)
# frame #6: <unknown function> + 0x201b06 (0x564388f2fb06 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #7: _PyObject_MakeTpCall + 0x253 (0x564388f0e8b3 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #8: <unknown function> + 0x2301b6 (0x564388f5e1b6 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #9: <unknown function> + 0x2190dc (0x564388f470dc in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #10: <unknown function> + 0x1e0be1 (0x564388f0ebe1 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #11: <unknown function> + 0xf874 (0x772e09af0874 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/site-packages/torchaudio/lib/_torchaudio.so)
# frame #12: _PyObject_MakeTpCall + 0x253 (0x564388f0e8b3 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #13: _PyEval_EvalFrameDefault + 0x716 (0x564388f1c3b6 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #14: _PyFunction_Vectorcall + 0x181 (0x564388f3f981 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #15: <unknown function> + 0x218d3c (0x564388f46d3c in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #16: _PyObject_MakeTpCall + 0x233 (0x564388f0e893 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #17: _PyEval_EvalFrameDefault + 0x716 (0x564388f1c3b6 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #18: <unknown function> + 0x2a5a8d (0x564388fd3a8d in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #19: PyEval_EvalCode + 0x9f (0x564388fd311f in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #20: <unknown function> + 0x2bc6ee (0x564388fea6ee in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #21: _PyEval_EvalFrameDefault + 0x38c0 (0x564388f1f560 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #22: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #23: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #24: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #25: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #26: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #27: <unknown function> + 0x2ba5b7 (0x564388fe85b7 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #28: _PyEval_EvalFrameDefault + 0x3a36 (0x564388f1f6d6 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #29: <unknown function> + 0x2308d4 (0x564388f5e8d4 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #30: <unknown function> + 0x2300be (0x564388f5e0be in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #31: PyObject_Call + 0x130 (0x564388f496b0 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #32: _PyEval_EvalFrameDefault + 0x4a44 (0x564388f206e4 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #33: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #34: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #35: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #36: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #37: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #38: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #39: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #40: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #41: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #42: _PyEval_EvalFrameDefault + 0x3387 (0x564388f1f027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #43: <unknown function> + 0x2b9c39 (0x564388fe7c39 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #44: <unknown function> + 0x78b6 (0x772e526f68b6 in /home/olly/miniconda3/envs/bird_audio_ml/lib/python3.11/lib-dynload/_asyncio.cpython-311-x86_64-linux-gnu.so)
# frame #45: <unknown function> + 0x2003fa (0x564388f2e3fa in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #46: <unknown function> + 0x199fb5 (0x564388ec7fb5 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #47: <unknown function> + 0x19c065 (0x564388eca065 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #48: <unknown function> + 0x1fafbf (0x564388f28fbf in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #49: _PyEval_EvalFrameDefault + 0x8c34 (0x564388f248d4 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #50: <unknown function> + 0x2a5a8d (0x564388fd3a8d in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #51: PyEval_EvalCode + 0x9f (0x564388fd311f in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #52: <unknown function> + 0x2bc6ee (0x564388fea6ee in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #53: <unknown function> + 0x1fafbf (0x564388f28fbf in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #54: PyObject_Vectorcall + 0x2c (0x564388f28eac in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #55: _PyEval_EvalFrameDefault + 0x716 (0x564388f1c3b6 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #56: _PyFunction_Vectorcall + 0x181 (0x564388f3f981 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #57: <unknown function> + 0x2cf158 (0x564388ffd158 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #58: Py_RunMain + 0x139 (0x564388ffcad9 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #59: Py_BytesMain + 0x37 (0x564388fc3027 in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)
# frame #60: <unknown function> + 0x2a1ca (0x772e5302a1ca in /lib/x86_64-linux-gnu/libc.so.6)
# frame #61: __libc_start_main + 0x8b (0x772e5302a28b in /lib/x86_64-linux-gnu/libc.so.6)
# frame #62: <unknown function> + 0x294ecd (0x564388fc2ecd in /home/olly/miniconda3/envs/bird_audio_ml/bin/python)

# %%
play_audio(tier1_files[100])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play_audio(tier1_files[50])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
